# %%
import pyodbc


server = 'syn-rt-prd-unity.sql.azuresynapse.net'
database = 'syndwrtprdunity'
username = 'byambadorjme@riotinto.com'  
driver = '{ODBC Driver 17 for SQL Server}'

connection_string = f"""
    DRIVER={driver};
    SERVER={server};
    DATABASE={database};
    UID={username};
    Authentication=ActiveDirectoryInteractive;
    Encrypt=yes;
    TrustServerCertificate=no;
    Connection Timeout=30;
"""


connection = pyodbc.connect(connection_string)

# %%
cursor = connection.cursor()

views = ('vw_udllibbwpbw__bic_hprocess',
'vw_udllibbwpbw__bic_passet',
'vw_udllibbwpbw__bic_pop_resp',
'vw_udllibbwpbw__bic_pplant',
'vw_udllibbwpbw__bic_tasset',
'vw_udllibbwpbw__bic_tasset_cat',
'vw_udllibbwpbw__bic_tasset_cls',
'vw_udllibbwpbw__bic_tasset_tec',
'vw_udllibbwpbw__bic_tasset_typ',
'vw_udllibbwpbw__bic_tmaterial',
'vw_udllibbwpbw__bic_top_resp',
'vw_udllibbwpbw__bic_tprocess',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4021_q01_last_snapshot_backlog_age_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4046_schedule_compliance_gi_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4050_scheduled_work_gi_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4156_primary_maintenance_call_compliance_gi_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4171_use_of_resource_availability_gi_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4228_maintenance_plans_functional_location_cri_lookup',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4230_criticality_profile_asset_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4231_detailed_asset_criticality_list',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4552_work_event_profile_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4705_zbb_quality_local_gi_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r4705_zbb_quality_usd_gi_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r5050_material_movement_analysis_prodfactsheet_governed',
'vw_udlriotintosydneyinternalbwpdi1bwpsapbwp_bwp_r5100_rio_total_material_moved_actual_governed',
'vw_UDLRIOTINTOSYDNEYINTERNALBWPDI1BWPSAPBWP_BWP_R5305_PRODUCT_QUALITY_SUMMARY_DEMO',
'vw_udlordw_dim_consist',
'vw_udlordw_dim_fixedplantasset',
'vw_udlordw_dim_hmeasset',
'vw_udlordw_dim_hmeassetfunction',
'vw_udlordw_dim_location',
'vw_udlordw_dim_material',
'vw_udlordw_dim_productiontype',
'vw_udlordw_dim_railyard',
'vw_udlordw_dim_site',
'vw_udlordw_dim_tag',
'vw_udlordw_dim_tagcycle',
'vw_udlordw_dim_tagcycledetails',
'vw_UDLORDW_DIM_TAGQUEUEINGPROCESS',
'vw_UDLORDW_DIM_TIMEUSAGETAG',
'vw_udlordw_dim_trainname',
'vw_udlordw_fact_traindumpconfirmed',
'vw_udlordw_public_v2_cs_fact_hmecycle',
'vw_udlordw_public_v2_cs_fact_hmetimeusage',
'vw_udlordw_public_v2_dim_timeusage',
'vw_udlordw_public_v2_fact_confirmedproduction',
'vw_UDLORDW_PUBLIC_V2_FACT_PLANANDSCHEDULE',
'vw_UDLORDW_PUBLIC_V2_FACT_TRAINDUMP',
'vw_udlordw_public_v3_cs_fact_tagcycle',
'vw_udlordw_public_v3_cs_fact_tagtimeusage',
'vw_UDLORDW_PUBLIC_V3_FACT_TAGQUEUEINGDURATION',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_bicpasset',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_bictasset',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_bictasset_cat',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_bictasset_cls',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_bictasset_tec',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_bictasset_typ',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4021_pacal_last_snapshot_backlog_age',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4046_pacal_schedule_compliance',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4050_pacal_scheduled_work',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4156_pacal_primary_maintenance_call_compliance',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4171_pacal_use_of_resource_availability_gi',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4228_pacal_maintenance_plans_functional_location_cri_lookup',
'vw_UDLRIOTINTOSYDNEYINTERNALPACLDPBP01PBPSAPPBP_PBP_R4230_PACAL_CRITICALITY_PROFILE_ASSET',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4552_pacal_work_event_profile',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4705_pacal_zbb_quality_local_gi',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r4705_pacal_zbb_quality_usd_gi',
'vw_udlriotintosydneyinternalpacldpbp01pbpsappbp_pbp_r5050_pacal_material_movement_analysis_prodfactsheet',
'vw_UDLKUCMMRSCM_MMRS_CS_EVENT_V2',
'vw_UDLKUCMMRSCM_MMRS_CYCLE',
'vw_UDLKUCMMRSCM_mmrs_LOCATION',
'vw_UDLKUCMMRSCM_mmrs_RF_MATERIAL',
'vw_UDLKUCMMRSCM_mmrs_RF_TIMECODE',
'vw_udlkucmmrscm_mmrs_rf_timecode_map',
'vw_UDLKUCMMRSCM_mmrs_RF_UNIT',
'vw_UDLKUCMMRSCM_mmrs_UNIT_FLEET_FLEETTYPE',
'vw_udlkucmmrscm_mmrs_vw_cycle',
'vw_udlkucmmrscm_mmrs_vw_event',
'vw_udlkucmmrscm_mmrs_vw_location',
'vw_udlkucmmrscm_mmrs_vw_rf_material',
'vw_udlkucmmrscm_mmrs_vw_rf_timecode',
'vw_udlkucmmrscm_mmrs_vw_rf_unit',
'vw_udlkucmmrscm_mmrs_vw_unit_fleet_fleettype',
'vw_udlausydsqlq93dspqatdbviews_dbo_unity_tum_l1',
'vw_udludltbdviewsausydsql99_dbo_ttam_ph_sitehierarchyexport',
'vw_udludltbdviewsausydsql99_dbo_tx_dcam_ph_webunity_assetnodehierarchy',
'vw_udludltbdviewsausydsql99_dbo_txrefdata_unity_hme_ao_extract',
'vw_udludltbdviewsausydsql99_dbo_txrefdata_unity_hme_asset_extract',
'vw_udludltbdviewsausydsql99_dbo_txrefdata_unity_hme_rato_extract',
'vw_udludltbdviewsausydsql99_dbo_webassetweightexportsel',
'vw_udludltbdviewsausydsql99_dbo_webpayloadtargetexportsel',
'vw_udludltbdviewsausydsql99_dbo_websitehierarchyexport',
'vw_UDLBORONMMRS_MMRS_CS_CYCLE',
'vw_UDLBORONMMRS_MMRS_CS_EVENT',
'vw_udlboronmmrs_mmrs_cs_vw_cycle',
'vw_udlboronmmrs_mmrs_cs_vw_event',
'vw_UDLBORONMMRS_MMRS_LOCATION',
'vw_UDLBORONMMRS_MMRS_RF_MATERIAL',
'vw_UDLBORONMMRS_MMRS_RF_TIMECode',
'vw_udlboronmmrs_mmrs_rf_timecode_map',
'vw_UDLBORONMMRS_MMRS_RF_UNIT',
'vw_UDLBORONMMRS_MMRS_UNIT_FLEET_FLEETTYPE',
'vw_udlboronmmrs_mmrs_vw_location',
'vw_udlboronmmrs_mmrs_vw_rf_material',
'vw_udlboronmmrs_mmrs_vw_rf_timecode',
'vw_udlboronmmrs_mmrs_vw_rf_unit',
'vw_udlboronmmrs_mmrs_vw_unit_fleet_fleettype',
'vw_UDLCMAUGOVZSQL1_LOCATION',
'vw_UDLCMAUGOVZSQL1_MMRS_CS_CYCLE',
'vw_UDLCMAUGOVZSQL1_MMRS_CS_EVENT',
'vw_udlcmaugovzsql1_mmrs_cs_vw_cycle',
'vw_udlcmaugovzsql1_mmrs_cs_vw_event',
'vw_UDLCMAUGOVZSQL1_mmrs_RF_MATERIAL',
'vw_udlcmaugovzsql1_mmrs_vw_rf_material',
'vw_UDLCMAUGOVZSQL1_RF_TIMECode',
'vw_udlcmaugovzsql1_rf_timecode_map',
'vw_UDLCMAUGOVZSQL1_RF_UNIT',
'vw_UDLCMAUGOVZSQL1_UNIT_FLEET_FLEETTYPE',
'vw_udlcmaugovzsql1_vw_location',
'vw_udlcmaugovzsql1_vw_rf_timecode',
'vw_udlcmaugovzsql1_vw_rf_unit',
'vw_udlcmaugovzsql1_vw_unit_fleet_fleettype',
'vw_UDLMMRSIOC_LOCATION',
'vw_UDLMMRSIOC_MMRS_CS_CYCLE',
'vw_UDLMMRSIOC_MMRS_CS_EVENT',
'vw_udlmmrsioc_mmrs_cs_vw_cycle',
'vw_udlmmrsioc_mmrs_cs_vw_event',
'vw_UDLMMRSIOC_RF_MATERIAL',
'vw_UDLMMRSIOC_RF_TIMECODE',
'vw_UDLMMRSIOC_RF_TIMECODE_MAP',
'vw_UDLMMRSIOC_RF_UNIT',
'vw_UDLMMRSIOC_UNIT_FLEET_FLEETTYPE',
'vw_udlmmrsioc_vw_location',
'vw_udlmmrsioc_vw_rf_material',
'vw_udlmmrsioc_vw_rf_timecode',
'vw_udlmmrsioc_vw_rf_timecode_map',
'vw_udlmmrsioc_vw_rf_unit',
'vw_udlmmrsioc_vw_unit_fleet_fleettype',
'vw_UDLMMRSKUC_LOCATION',
'vw_UDLMMRSKUC_MMRS_CS_CYCLE',
'vw_UDLMMRSKUC_MMRS_CS_EVENT',
'vw_udlmmrskuc_mmrs_cs_vw_cycle',
'vw_udlmmrskuc_mmrs_cs_vw_event',
'vw_UDLMMRSKUC_RF_MATERIAL',
'vw_udlmmrskuc_rf_timecode',
'vw_udlmmrskuc_rf_timecode_map',
'vw_udlmmrskuc_rf_unit',
'vw_UDLMMRSKUC_UNIT_FLEET_FLEETTYPE',
'vw_udlmmrskuc_vw_location',
'vw_udlmmrskuc_vw_rf_material',
'vw_udlmmrskuc_vw_unit_fleet_fleettype',
'vw_UDLCONNECTEDMINE_LOCATION',
'vw_UDLCONNECTEDMINE_MMRS_CS_CYCLE',
'vw_UDLCONNECTEDMINE_MMRS_CS_EVENT',
'vw_udlconnectedmine_mmrs_cs_vw_cycle',
'vw_udlconnectedmine_mmrs_cs_vw_event',
'vw_UDLCONNECTEDMINE_RF_MATERIAL',
'vw_UDLCONNECTEDMINE_RF_TIMECODE',
'vw_udlconnectedmine_rf_timecode_map',
'vw_UDLCONNECTEDMINE_RF_UNIT',
'vw_UDLCONNECTEDMINE_UNIT_FLEET_FLEETTYPE',
'vw_udlconnectedmine_vw_location',
'vw_udlconnectedmine_vw_rf_material',
'vw_udlconnectedmine_vw_rf_timecode',
'vw_udlconnectedmine_vw_rf_unit',
'vw_udlconnectedmine_vw_unit_fleet_fleettype',
'vw_UDLCMAUWEISQL5_LOCATION',
'vw_UDLCMAUWEISQL5_MMRS_CS_CYCLE',
'vw_UDLCMAUWEISQL5_MMRS_CS_EVENT',
'vw_udlcmauweisql5_mmrs_cs_vw_cycle',
'vw_udlcmauweisql5_mmrs_cs_vw_event',
'vw_UDLCMAUWEISQL5_RF_MATERIAL',
'vw_UDLCMAUWEISQL5_RF_TIMECODE',
'vw_udlcmauweisql5_rf_timecode_map',
'vw_UDLCMAUWEISQL5_RF_UNIT',
'vw_UDLCMAUWEISQL5_UNIT_FLEET_FLEETTYPE',
'vw_udlcmauweisql5_vw_location',
'vw_udlcmauweisql5_vw_rf_material',
'vw_udlcmauweisql5_vw_rf_timecode',
'vw_udlcmauweisql5_vw_rf_unit',
'vw_udlcmauweisql5_vw_unit_fleet_fleettype',
'vw_udlpisystems_globalpi_pm_reporting_data_cu',
'vw_udlpisystems_pm_reporting_locations_hierarchy',
'vw_udlrepository_globalpi_cs_pm_reporting_data_recovery',
'vw_udlrepository_globalpi_cs_yarwun_mis_tags',
'vw_odp_dim_fixedplantmetric',
'vw_odp_dim_material',
'vw_odp_dim_shift',
'vw_odp_dim_site',
'vw_odp_dim_target',
'vw_odp_fact_fixedplantproductionshift',
'vw_odp_fact_fixedplanttarget',
'vw_udldwbdp_dal_dim_material',
'vw_udlpisystems_opsdata_cs_mis_rtit_sandmetrics',
'vw_udlpisystems_opsdata_cs_pm_reporting_data',
'vw_udlpisystems_opsdata_cs_pm_reporting_recovery_data',
'vw_UDLPISYSTEMS_OPSDATA_MIS_RTIT_HEADGRADE',
'vw_udltimeutilisation_dbo_dimcause',
'vw_udltimeutilisation_dbo_dimcausecategory',
'vw_udltimeutilisation_dbo_dimequipment',
'vw_udltimeutilisation_dbo_downtimeaggbyday',
'vw_udlauperora15_aps_plan_comparisons_cs_planned_production',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_dim_drillhole',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_dim_drillinglocation',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_dim_rig',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_dim_timeelements',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_fact_drillingcorerecovery',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_fact_drillingmetres',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_fact_drillingnonoperatinghours',
'vw_udlrtxgomsdatawarehouseausydsql145_primemetrics_fact_drillingoperatinghours',
'vw_udlrepository_average_efh',
'vw_udlprogramtracker_activities',
'vw_udlprogramtracker_dbo_drill_design_holes',
'vw_udlprogramtracker_dbo_projects',
'vw_udlprogramtracker_downtimestandbyreasons',
'vw_udlprogramtracker_drill_design_areas',
'vw_udlprogramtracker_drill_design_rigs',
'vw_udlprogramtracker_geed_corerecoverynew',
'vw_udlprogramtracker_geed_drillingmetresandhours',
'vw_udlprogramtracker_geed_drillingmetresandhours_wtdtsb',
'vw_udlprogramtracker_geed_hydrometresandhours',
'vw_udlprogramtracker_geed_hydrometresandhours_wtdtsb',
'vw_udlprogramtracker_geed_hydroplandata',
'vw_udlprogramtracker_geed_projects',
'vw_udlprogramtracker_geed_protrakcubeviewdrillingcosts',
'vw_udlprogramtracker_geed_protrakhydrocosts',
'vw_udlprogramtracker_hydro_bore_hole_design',
'vw_udlprogramtracker_hydro_dashboard_borehole',
'vw_udlprogramtracker_hydro_dashboard_summary2',
'vw_udlprogramtracker_project_planning_rigs',
'vw_udlprogramtracker_protrakplanmetres',
'vw_udlprogramtracker_rig_types',
'vw_udlprogramtracker_timeelements',
'vw_udlrcmlacqrdprod_dbo_cs_uv_duration',
'vw_udlrcmlacqrdprod_dbo_uv_coreloss',
'vw_udlrcmlacqrdprod_dbo_uv_holedepthbyshift',
'vw_udlrcmlacqrdprod_dbo_uv_legend',
'vw_udlrcmlacqrdprod_dbo_uv_plannedholes',
'vw_udlrcmlacqrdprod_dbo_uv_rigs',
'vw_udlrcmlacqrdprod_qv_ac_activityreportcostdetails_ro',
'vw_udlrcmlacqrdprod_uv_activities',
'vw_udlrtaodpaluminiumcasting_scorecard_cs_vscorecardresult',
'vw_udlrtaodpaluminiumreduction_redu_vscorecardresult',
'vw_UDLKUCPRODSTAT_VW_CONCENTRATORMETRICS',
'vw_udlwinuacqlogging_dbo_holedetails',
'vw_udlwinuacqlogging_dbo_uv_activities',
'vw_udlwinuacqlogging_dbo_uv_coreloss',
'vw_udlwinuacqlogging_dbo_uv_duration',
'vw_udlwinuacqlogging_dbo_uv_holedepthbyshift',
'vw_udlwinuacqlogging_dbo_uv_legend',
'vw_udlwinuacqlogging_dbo_uv_plannedholes',
'vw_udlwinuacqlogging_dbo_uv_rigs',
'vw_udldwbdp_dal_cs_fixedplantmetrics_prime',
'vw_udllibecprtp_sap_cs_qmfe',
'vw_udlenvirosql_sf_groundwaterdewateringmetrics')

all_views = []


for view in views:
    row = []
    row.append(view)
    try:
        query = f"SELECT TOP 1 1 FROM [DAL_V].[{view}]"
        cursor.execute(query)
        cursor.fetchone()
        row.append("Accessible")
        row.append("")
    except Exception as e:
        row.append("Access Denied")
        row.append(str(e))
        
    all_views.append(row)
cursor.close()
connection.close()

# %%
import pandas as pd

# %%
df = pd.DataFrame(all_views, columns=['View Name', 'Access Status', 'Error Message'])

# %%
df
# Out:
#                                            View Name  Access Status  \
# 0                       vw_udllibbwpbw__bic_hprocess     Accessible
# 1                         vw_udllibbwpbw__bic_passet     Accessible
# 2                       vw_udllibbwpbw__bic_pop_resp     Accessible
# 3                         vw_udllibbwpbw__bic_pplant     Accessible
# 4                         vw_udllibbwpbw__bic_tasset     Accessible
# ..                                               ...            ...
# 250         vw_udlwinuacqlogging_dbo_uv_plannedholes  Access Denied
# 251                 vw_udlwinuacqlogging_dbo_uv_rigs     Accessible
# 252       vw_udldwbdp_dal_cs_fixedplantmetrics_prime     Accessible
# 253                      vw_udllibecprtp_sap_cs_qmfe     Accessible
# 254  vw_udlenvirosql_sf_groundwaterdewateringmetrics     Accessible
#
#                                          Error Message
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# ...

# %%
('42S02', "[42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Invalid object name 'DAL_V.vw_udlwinuacqlogging_dbo_uv_plannedholes'. (208) (SQLExecDirectW)")

# %%
('42S02', "[42S02] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Invalid object name 'DAL_V.vw_UDLCMAUGOVZSQL1_MMRS_CS_CYCLE'. (208) (SQLExecDirectW)")

# %%
import numpy as np

# %%
df = (
    df
    .assign(
        ErrorType = lambda x: np.where(
            x['Error Message'].str.contains('Invalid object name'), 'Invalid object name',
            np.where(x['Error Message'].str.contains('permission'), 'Permission Denied', 'Others')
        )
    )
)

# %%
df.to_excel('view_access_report.xlsx', index=False)

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import networkx as nx

# Data (parent -> child edges)
edges = [
    ("nzas_vc_tum_nzas_green_carbon", "nzas_vc_tum_nzas_green_stocks_stp"),
    ("nzas_vc_tum_nzas_green_stocks_stp", "nzas_vc_tum_nzas_carbon_bake"),
    ("nzas_vc_tum_nzas_carbon_bake", "nzas_vc_tum_nzas_bake_stocks_stp"),
    ("nzas_vc_tum_nzas_bake_stocks_stp", "nzas_vc_tum_nzas_rodding"),
    ("nzas_vc_tum_nzas_rodding", "nzas_vc_tum_nzas_cast_anodes_stp"),
    ("nzas_vc_tum_nzas_cast_anodes_stp", "nzas_vc_tum_nzas_reduction"),
    ("nzas_vc_tum_nzas_reduction", "nzas_vc_tum_nzas_metal_inv_stp"),
    ("nzas_vc_tum_nzas_metal_inv_stp", "nzas_vc_tum_nzas_casthouse"),
    ("nzas_vc_tum_nzas_casthouse", "nzas_vc_tum_nzas_saleable_metal_stp"),
]

G = nx.DiGraph()
G.add_edges_from(edges)

# %%
edges_dict = []
for edge in edges:
    edges_dict.append({'parent_value_chain_node_id': edge[0], 'child_value_chain_node_id': edge[1]})

# %%
G = nx.DiGraph()

# %%
for row in edges_dict:
    G.add_edge(
        row["parent_value_chain_node_id"], row["child_value_chain_node_id"]
    )

# %%
UG = G.to_undirected()

# %%
components = list(nx.connected_components(UG))

# %%
nx.closeness_centrality(UG, wf_improved=True)
# Out:
# {'nzas_vc_tum_nzas_green_carbon': 0.2,
#  'nzas_vc_tum_nzas_green_stocks_stp': 0.24324324324324326,
#  'nzas_vc_tum_nzas_carbon_bake': 0.2903225806451613,
#  'nzas_vc_tum_nzas_bake_stocks_stp': 0.3333333333333333,
#  'nzas_vc_tum_nzas_rodding': 0.36,
#  'nzas_vc_tum_nzas_cast_anodes_stp': 0.36,
#  'nzas_vc_tum_nzas_reduction': 0.3333333333333333,
#  'nzas_vc_tum_nzas_metal_inv_stp': 0.2903225806451613,
#  'nzas_vc_tum_nzas_casthouse': 0.24324324324324326,
#  'nzas_vc_tum_nzas_saleable_metal_stp': 0.2}

# %%
shortest_path_lengths = dict(nx.shortest_path_length(UG)) #calc_longest_path(G)

# %%
shortest_path_lengths
# Out:
# {'nzas_vc_tum_nzas_green_carbon': {'nzas_vc_tum_nzas_green_carbon': 0,
#   'nzas_vc_tum_nzas_green_stocks_stp': 1,
#   'nzas_vc_tum_nzas_carbon_bake': 2,
#   'nzas_vc_tum_nzas_bake_stocks_stp': 3,
#   'nzas_vc_tum_nzas_rodding': 4,
#   'nzas_vc_tum_nzas_cast_anodes_stp': 5,
#   'nzas_vc_tum_nzas_reduction': 6,
#   'nzas_vc_tum_nzas_metal_inv_stp': 7,
#   'nzas_vc_tum_nzas_casthouse': 8,
#   'nzas_vc_tum_nzas_saleable_metal_stp': 9},
#  'nzas_vc_tum_nzas_green_stocks_stp': {'nzas_vc_tum_nzas_green_stocks_stp': 0,
#   'nzas_vc_tum_nzas_carbon_bake': 1,
#   'nzas_vc_tum_nzas_bake_stocks_stp': 2,
#   'nzas_vc_tum_nzas_rodding': 3,
#   'nzas_vc_tum_nzas_cast_anodes_stp': 4,
#   'nzas_vc_tum_nzas_reduction': 5,
#   'nzas_vc_tum_nzas_metal_inv_stp': 6,
#   'nzas_vc_tum_nzas_casthouse': 7,
#   'nzas_vc_tum_nzas_saleable_metal_stp': 8},
#  'nzas_vc_tum_nzas_carbon_bake': {'nzas_vc_tum_nzas_carbon_bake': 0,
#   'nzas_vc_tum_nzas_bake_stocks_stp': 1,
#   'nzas_vc_tum_nzas_rodding': 2,
# ...
