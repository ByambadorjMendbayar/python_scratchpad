# %% [markdown]
# # Synapse → Databricks Table Migration
#
# Reads table definitions from Synapse Analytics, creates matching tables in Databricks, and ingests data.
# Runs locally using `pyodbc` (ActiveDirectoryInteractive) and `databricks-sql-connector`.

# %%
import os
import pyodbc
from databricks import sql
import polars as pl
import math
from datetime import datetime, date, time
from decimal import Decimal

# ─── Synapse Connection ────────────────────────────────────────────────────────
synapse_server = "syn-rt-prd-unity.sql.azuresynapse.net"
synapse_database = "syndwrtprdunity"
synapse_username = "byambadorjme@riotinto.com"
synapse_driver = "{ODBC Driver 17 for SQL Server}"
synapse_source_schema = "MDE"

synapse_connection_string = f"""
    DRIVER={synapse_driver};
    SERVER={synapse_server};
    DATABASE={synapse_database};
    UID={synapse_username};
    Authentication=ActiveDirectoryInteractive;
    Encrypt=yes;
    TrustServerCertificate=no;
    Connection Timeout=30;
"""

# ─── Databricks Connection ─────────────────────────────────────────────────────
databricks_access_token = os.environ["DATABRICKS_TOKEN"]
databricks_server_hostname = "adb-2439498039309203.3.azuredatabricks.net"
databricks_http_path = "/sql/1.0/warehouses/e7d134c4348ac8b5"
databricks_target_catalog = "_ogr_azr_syd_dev"       # TODO: change to your target catalog
databricks_target_schema = "mde"                  # TODO: change to your target schema

# ─── Tables to migrate (schema.table from Synapse) ─────────────────────────────
tables_to_migrate = [
    "MDE.midas_annualplan",
    "MDE.midas_basemetric",
    "MDE.midas_dataflow",
    "MDE.midas_dataflowdependency",
    "MDE.midas_eedrillingprojectlocations",
    "MDE.midas_eedrillingprojectlocationspattern",
    "MDE.midas_expitmovementactual",
    "MDE.midas_fixedplantmetricmapping",
    "MDE.midas_hmeassetactivitytype",
    "MDE.midas_hmeassetmapping",
    "MDE.midas_hmetummapping",
    "MDE.midas_manualbasemetrics",
    "MDE.midas_mdr",
    "MDE.midas_primegreatersites",
    "MDE.midas_publicholiday",
    "MDE.midas_recovery",
    "MDE.midas_sitemapping",
    "MDE.midas_sourcetable",
    "MDE.midas_spatialconformance",
    "MDE.gmr_basemeasure",
    "MDE.gmr_basemeasuremapping",
    "MDE.gmr_metric",
    "MDE.gmr_metricmapping",
    "MDE.gmr_metriccategory",
    "MDE.gmr_environment"
]

# ─── Batch size for inserts ─────────────────────────────────────────────────────
BATCH_SIZE = 500

# %%
# dev info
databricks_access_token = os.environ["DATABRICKS_DEV_TOKEN"]
databricks_server_hostname = "adb-7405619384118055.15.azuredatabricks.net"
databricks_http_path = "sql/protocolv1/o/7405619384118055/0602-020120-iu3w432w"
databricks_target_catalog = "_ogr_azr_syd_dev"       # TODO: change to your target catalog
databricks_target_schema = "mde"                  # TODO: change to your target schema

# tst info
databricks_access_token = os.environ["DATABRICKS_TST_TOKEN"]
databricks_server_hostname = "adb-7405606707500852.12.azuredatabricks.net"
databricks_http_path = "sql/protocolv1/o/7405606707500852/0706-031608-i6afsdy0"
databricks_target_catalog = "_ogr_azr_syd_tst"       # TODO: change to your target catalog
databricks_target_schema = "mde"                  # TODO: change to your target schema

# prd info
databricks_access_token = os.environ["DATABRICKS_PRD_TOKEN"]
databricks_server_hostname = "adb-7405610406720068.8.azuredatabricks.net"
databricks_http_path = "sql/protocolv1/o/7405610406720068/0706-031837-y5fhc80o"
databricks_target_catalog = "_ogr_azr_syd_prd"       # TODO: change to your target catalog
databricks_target_schema = "mde"                  # TODO: change to your target schema

# %%
# ─── Establish Connections ──────────────────────────────────────────────────────
print("Connecting to Synapse (browser auth prompt may appear)...")
synapse_conn = pyodbc.connect(synapse_connection_string)
print("✓ Synapse connected")

print("Connecting to Databricks...")
databricks_conn = sql.connect(
    server_hostname=databricks_server_hostname,
    http_path=databricks_http_path,
    access_token=databricks_access_token,
)
databricks_cursor = databricks_conn.cursor()
print("✓ Databricks connected")

# Ensure target schema exists
databricks_cursor.execute(
    f"CREATE SCHEMA IF NOT EXISTS `{databricks_target_catalog}`.`{databricks_target_schema}`"
)
print(f"✓ Schema {databricks_target_catalog}.{databricks_target_schema} ready")
# Out:
# Connecting to Synapse (browser auth prompt may appear)...
# ✓ Synapse connected
# Connecting to Databricks...
# ✓ Databricks connected
# ✓ Schema _ogr_azr_syd_dev.mde ready

# %%
# ─── Type Mapping & Helper Functions ───────────────────────────────────────────

SYNAPSE_TO_DATABRICKS_TYPE = {
    "bigint": "BIGINT",
    "int": "INT",
    "smallint": "SMALLINT",
    "tinyint": "TINYINT",
    "bit": "BOOLEAN",
    "float": "DOUBLE",
    "real": "FLOAT",
    "decimal": "DECIMAL",
    "numeric": "DECIMAL",
    "money": "DECIMAL(19,4)",
    "smallmoney": "DECIMAL(10,4)",
    "varchar": "STRING",
    "nvarchar": "STRING",
    "char": "STRING",
    "nchar": "STRING",
    "text": "STRING",
    "ntext": "STRING",
    "date": "DATE",
    "datetime": "TIMESTAMP",
    "datetime2": "TIMESTAMP",
    "smalldatetime": "TIMESTAMP",
    "datetimeoffset": "STRING",
    "time": "STRING",
    "uniqueidentifier": "STRING",
    "varbinary": "BINARY",
    "binary": "BINARY",
    "image": "BINARY",
    "xml": "STRING",
    "sql_variant": "STRING",
}


def get_databricks_type(synapse_type, num_precision, num_scale):
    """Map a Synapse data type to a Databricks SQL type."""
    base = synapse_type.strip().lower()
    if base in ("decimal", "numeric"):
        p = num_precision if num_precision is not None else 38
        s = num_scale if num_scale is not None else 0
        return f"DECIMAL({p},{s})"
    return SYNAPSE_TO_DATABRICKS_TYPE.get(base, "STRING")


def format_sql_value(val):
    """Format a Python value as a Databricks SQL literal."""
    if val is None:
        return "NULL"
    if isinstance(val, bool):
        return "TRUE" if val else "FALSE"
    if isinstance(val, int):
        return str(val)
    if isinstance(val, float):
        if math.isnan(val) or math.isinf(val):
            return "NULL"
        return repr(val)
    if isinstance(val, Decimal):
        return str(val)
    if isinstance(val, datetime):
        return f"'{val.strftime('%Y-%m-%d %H:%M:%S.%f')}'"
    if isinstance(val, date):
        return f"'{val.isoformat()}'"
    if isinstance(val, time):
        return f"'{val.isoformat()}'"
    if isinstance(val, (bytes, bytearray)):
        return f"X'{val.hex()}'"
    # Default: treat as string, escape single quotes
    escaped = str(val).replace("'", "''")
    return f"'{escaped}'"

# %%
def migrate_table(
    synapse_conn,
    databricks_cursor,
    synapse_schema: str,
    synapse_table: str,
    dbx_catalog: str,
    dbx_schema: str,
    dbx_table: str,
    batch_size: int = 500,
):
    """Read schema + data from Synapse, create table in Databricks, and insert rows."""

    # ── 1. Read column metadata from Synapse ──
    schema_query = f"""
        SELECT COLUMN_NAME, DATA_TYPE,
               NUMERIC_PRECISION, NUMERIC_SCALE,
               ORDINAL_POSITION
        FROM INFORMATION_SCHEMA.COLUMNS
        WHERE TABLE_SCHEMA = '{synapse_schema}'
          AND TABLE_NAME   = '{synapse_table}'
        ORDER BY ORDINAL_POSITION
    """
    schema_df = pl.read_database(schema_query, synapse_conn)

    if schema_df.height == 0:
        print(f"  ⚠ No columns found for {synapse_schema}.{synapse_table} — skipping")
        return {"table": synapse_table, "status": "skipped", "reason": "no columns"}

    col_names = schema_df["COLUMN_NAME"].to_list()

    # ── 2. Build and execute CREATE TABLE DDL ──
    col_defs = []
    for row in schema_df.iter_rows(named=True):
        dbx_type = get_databricks_type(
            row["DATA_TYPE"], row["NUMERIC_PRECISION"], row["NUMERIC_SCALE"]
        )
        col_defs.append(f"    `{row['COLUMN_NAME']}` {dbx_type}")

    full_table = f"`{dbx_catalog}`.`{dbx_schema}`.`{dbx_table}`"
    ddl = f"CREATE OR REPLACE TABLE {full_table} (\n" + ",\n".join(col_defs) + "\n)"

    print(f"  Creating table {full_table} ({len(col_names)} columns)...")
    databricks_cursor.execute(ddl)

    # ── 3. Read all data from Synapse ──
    cols_sql = ", ".join(f"[{c}]" for c in col_names)
    data_query = f"SELECT {cols_sql} FROM [{synapse_schema}].[{synapse_table}]"

    print(f"  Reading data from {synapse_schema}.{synapse_table}...")
    data_df = pl.read_database(data_query, synapse_conn)
    total_rows = data_df.height
    print(f"  Fetched {total_rows:,} rows")

    if total_rows == 0:
        print(f"  ✓ Table created (empty)")
        return {"table": synapse_table, "status": "ok", "rows": 0}

    # ── 4. Insert in batches ──
    rows = data_df.rows()
    inserted = 0

    for i in range(0, total_rows, batch_size):
        batch = rows[i : i + batch_size]
        values_clauses = []
        for row in batch:
            formatted = ", ".join(format_sql_value(v) for v in row)
            values_clauses.append(f"({formatted})")

        insert_sql = f"INSERT INTO {full_table} VALUES\n" + ",\n".join(values_clauses)
        databricks_cursor.execute(insert_sql)
        inserted += len(batch)
        print(f"  Inserted {inserted:,}/{total_rows:,} rows", end="\r")

    print(f"  ✓ Inserted {inserted:,}/{total_rows:,} rows      ")
    return {"table": synapse_table, "status": "ok", "rows": inserted}

# %%
# ─── Run Migration for All Tables ──────────────────────────────────────────────
results = []

for i, qualified_name in enumerate(tables_to_migrate, 1):
    syn_schema, syn_table = qualified_name.split(".", 1)
    dbx_table = syn_table  # keep same table name in Databricks

    print(f"\n[{i}/{len(tables_to_migrate)}] {qualified_name}")
    try:
        result = migrate_table(
            synapse_conn=synapse_conn,
            databricks_cursor=databricks_cursor,
            synapse_schema=syn_schema,
            synapse_table=syn_table,
            dbx_catalog=databricks_target_catalog,
            dbx_schema=databricks_target_schema,
            dbx_table=dbx_table,
            batch_size=BATCH_SIZE,
        )
        results.append(result)
    except Exception as e:
        print(f"  ✗ ERROR: {e}")
        results.append({"table": syn_table, "status": "error", "reason": str(e)})

# ─── Summary ───────────────────────────────────────────────────────────────────
print("\n" + "=" * 60)
print("Migration Summary")
print("=" * 60)
summary_df = pl.DataFrame(results)
print(summary_df)
# Out:
# [1/25] MDE.midas_annualplan
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_annualplan` (12 columns)...
#   Reading data from MDE.midas_annualplan...
#   Fetched 7,836 rows
#   ✓ Inserted 7,836/7,836 rows
#
# [2/25] MDE.midas_basemetric
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_basemetric` (52 columns)...
#   Reading data from MDE.midas_basemetric...
#   Fetched 398 rows
#   ✓ Inserted 398/398 rows
#
# [3/25] MDE.midas_dataflow
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_dataflow` (15 columns)...
#   Reading data from MDE.midas_dataflow...
#   Fetched 590 rows
#   ✓ Inserted 590/590 rows
#
# [4/25] MDE.midas_dataflowdependency
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_dataflowdependency` (9 columns)...
#   Reading data from MDE.midas_dataflowdependency...
#   Fetched 75 rows
#   ✓ Inserted 75/75 rows
#
# [5/25] MDE.midas_eedrillingprojectlocations
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_eedrillingprojectlocations` (9 columns)...
#   Reading data from MDE.midas_eedrillingprojectlocations...
#   Fetched 1,220 rows
#   ✓ Inserted 1,220/1,220 rows
#
# [6/25] MDE.midas_eedrillingprojectlocationspattern
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_eedrillingprojectlocationspattern` (9 columns)...
#   Reading data from MDE.midas_eedrillingprojectlocationspattern...
#   Fetched 34 rows
#   ✓ Inserted 34/34 rows
#
# [7/25] MDE.midas_expitmovementactual
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_expitmovementactual` (10 columns)...
#   Reading data from MDE.midas_expitmovementactual...
#   Fetched 89 rows
#   ✓ Inserted 89/89 rows
#
# [8/25] MDE.midas_fixedplantmetricmapping
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_fixedplantmetricmapping` (11 columns)...
#   Reading data from MDE.midas_fixedplantmetricmapping...
#   Fetched 524 rows
#   ✓ Inserted 524/524 rows
#
# [9/25] MDE.midas_hmeassetactivitytype
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_hmeassetactivitytype` (10 columns)...
#   Reading data from MDE.midas_hmeassetactivitytype...
#   Fetched 22 rows
#   ✓ Inserted 22/22 rows
#
# [10/25] MDE.midas_hmeassetmapping
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_hmeassetmapping` (27 columns)...
#   Reading data from MDE.midas_hmeassetmapping...
#   Fetched 21 rows
#   ✓ Inserted 21/21 rows
#
# [11/25] MDE.midas_hmetummapping
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_hmetummapping` (17 columns)...
#   Reading data from MDE.midas_hmetummapping...
#   Fetched 35 rows
#   ✓ Inserted 35/35 rows
#
# [12/25] MDE.midas_manualbasemetrics
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_manualbasemetrics` (13 columns)...
#   Reading data from MDE.midas_manualbasemetrics...
#   Fetched 5,728 rows
#   ✓ Inserted 5,728/5,728 rows
#
# [13/25] MDE.midas_mdr
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_mdr` (19 columns)...
#   Reading data from MDE.midas_mdr...
#   Fetched 335 rows
#   ✓ Inserted 335/335 rows
#
# [14/25] MDE.midas_primegreatersites
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_primegreatersites` (13 columns)...
#   Reading data from MDE.midas_primegreatersites...
#   Fetched 473 rows
#   ✓ Inserted 473/473 rows
#
# [15/25] MDE.midas_publicholiday
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_publicholiday` (7 columns)...
#   Reading data from MDE.midas_publicholiday...
#   Fetched 30 rows
#   ✓ Inserted 30/30 rows
#
# [16/25] MDE.midas_recovery
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_recovery` (16 columns)...
#   Reading data from MDE.midas_recovery...
#   Fetched 229 rows
#   ✓ Inserted 229/229 rows
#
# [17/25] MDE.midas_sitemapping
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_sitemapping` (15 columns)...
#   Reading data from MDE.midas_sitemapping...
#   Fetched 486 rows
#   ✓ Inserted 486/486 rows
#
# [18/25] MDE.midas_sourcetable
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_sourcetable` (11 columns)...
#   Reading data from MDE.midas_sourcetable...
#   Fetched 255 rows
#   ✓ Inserted 255/255 rows
#
# [19/25] MDE.midas_spatialconformance
#   Creating table `_ogr_azr_syd_dev`.`mde`.`midas_spatialconformance` (13 columns)...
#   Reading data from MDE.midas_spatialconformance...
#   Fetched 2,622 rows
#   ✓ Inserted 2,622/2,622 rows
#
# [20/25] MDE.gmr_basemeasure
#   Creating table `_ogr_azr_syd_dev`.`mde`.`gmr_basemeasure` (20 columns)...
#   Reading data from MDE.gmr_basemeasure...
#   Fetched 200 rows
#   ✓ Inserted 200/200 rows
#
# [21/25] MDE.gmr_basemeasuremapping
#   Creating table `_ogr_azr_syd_dev`.`mde`.`gmr_basemeasuremapping` (19 columns)...
#   Reading data from MDE.gmr_basemeasuremapping...
#   Fetched 1,024 rows
#   ✓ Inserted 1,024/1,024 rows
#
# [22/25] MDE.gmr_metric
#   Creating table `_ogr_azr_syd_dev`.`mde`.`gmr_metric` (69 columns)...
#   Reading data from MDE.gmr_metric...
#   Fetched 845 rows
#   ✓ Inserted 845/845 rows
#
# [23/25] MDE.gmr_metricmapping
#   Creating table `_ogr_azr_syd_dev`.`mde`.`gmr_metricmapping` (20 columns)...
#   Reading data from MDE.gmr_metricmapping...
#   Fetched 4,273 rows
#   ✓ Inserted 4,273/4,273 rows
#
# [24/25] MDE.gmr_metriccategory
#   Creating table `_ogr_azr_syd_dev`.`mde`.`gmr_metriccategory` (5 columns)...
#   Reading data from MDE.gmr_metriccategory...
#   Fetched 69 rows
#   ✓ Inserted 69/69 rows
#
# [25/25] MDE.gmr_environment
#   Creating table `_ogr_azr_syd_dev`.`mde`.`gmr_environment` (15 columns)...
#   Reading data from MDE.gmr_environment...
#   Fetched 51 rows
#   ✓ Inserted 51/51 rows
#
# ============================================================
# Migration Summary
# ============================================================
# shape: (25, 3)
# ┌─────────────────────────────────┬────────┬──────┐
# │ table                           ┆ status ┆ rows │
# │ ---                             ┆ ---    ┆ ---  │
# │ str                             ┆ str    ┆ i64  │
# ╞═════════════════════════════════╪════════╪══════╡
# │ midas_annualplan                ┆ ok     ┆ 7836 │
# │ midas_basemetric                ┆ ok     ┆ 398  │
# │ midas_dataflow                  ┆ ok     ┆ 590  │
# │ midas_dataflowdependency        ┆ ok     ┆ 75   │
# │ midas_eedrillingprojectlocatio… ┆ ok     ┆ 1220 │
# │ …                               ┆ …      ┆ …    │
# │ gmr_basemeasuremapping          ┆ ok     ┆ 1024 │
# │ gmr_metric                      ┆ ok     ┆ 845  │
# │ gmr_metricmapping               ┆ ok     ┆ 4273 │
# │ gmr_metriccategory              ┆ ok     ┆ 69   │
# │ gmr_environment                 ┆ ok     ┆ 51   │
# └─────────────────────────────────┴────────┴──────┘

# %% [markdown]
# ## Generate Power Automate Sync Configuration Table
# Queries Synapse `INFORMATION_SCHEMA.COLUMNS` for all 25 MDE tables and builds the config rows:
# `sync_table_name`, `last_sync_timestamp`, `databricks_target_table`, `column_list`, `primary_key_column`, `phantom_row_sql`

# %%
# ─── Query all column metadata from Synapse in one shot ────────────────────────
table_names_sql = ", ".join(
    f"'{t.split('.', 1)[1]}'" for t in tables_to_migrate
)

all_columns_query = f"""
    SELECT
        TABLE_NAME,
        COLUMN_NAME,
        DATA_TYPE,
        NUMERIC_PRECISION,
        NUMERIC_SCALE,
        ORDINAL_POSITION
    FROM INFORMATION_SCHEMA.COLUMNS
    WHERE TABLE_SCHEMA = '{synapse_source_schema}'
      AND TABLE_NAME IN ({table_names_sql})
    ORDER BY TABLE_NAME, ORDINAL_POSITION
"""

all_columns_df = pl.read_database(all_columns_query, synapse_conn)
print(f"Fetched {all_columns_df.height} column definitions across "
      f"{all_columns_df['TABLE_NAME'].n_unique()} tables")


# ─── Map Synapse type → Databricks SQL literal type ────────────────────────────
def to_dbx_type(data_type, num_precision, num_scale):
    base = data_type.strip().lower()
    if base in ("decimal", "numeric"):
        p = num_precision if num_precision is not None else 38
        s = num_scale if num_scale is not None else 0
        return f"DECIMAL({p},{s})"
    return SYNAPSE_TO_DATABRICKS_TYPE.get(base, "STRING")


# ─── Build config rows ────────────────────────────────────────────────────────
DBX_CATALOG = "_ogr_azr_syd_dev"
DBX_SCHEMA  = "mde"

config_rows = []

for qualified in tables_to_migrate:
    _, table = qualified.split(".", 1)

    cols_df = (
        all_columns_df
        .filter(pl.col("TABLE_NAME") == table)
        .sort("ORDINAL_POSITION")
    )

    if cols_df.height == 0:
        print(f"⚠  {table}: no columns found — skipped")
        continue

    # Column names (alphabetically sorted, matching the example)
    col_names = sorted(cols_df["COLUMN_NAME"].str.to_lowercase().to_list())

    # Primary key — Dataverse convention: <tablename>id
    pk = f"{table}id"
    if pk not in col_names:
        # fallback: first column whose name ends with 'id'
        id_cols = [c for c in col_names if c.endswith("id")]
        pk = id_cols[0] if id_cols else col_names[0]

    # Sync table name — Dataverse entity-set name is logical name + 's'
    sync_name = table + "s"

    # Databricks target
    dbx_target = f"{DBX_CATALOG}.{DBX_SCHEMA}.{table}"

    # Phantom row SQL
    # Build in column_list (alphabetical) order so positions match
    cast_parts = []
    for c in col_names:
        row = cols_df.filter(pl.col("COLUMN_NAME").str.to_lowercase() == c).row(0, named=True)
        dbx_type = to_dbx_type(row["DATA_TYPE"], row["NUMERIC_PRECISION"], row["NUMERIC_SCALE"])
        cast_parts.append(f"CAST(NULL AS {dbx_type}) AS {c}")

    phantom_sql = "SELECT " + ", ".join(cast_parts) + " WHERE 1=0"

    config_rows.append({
        "sync_table_name": sync_name,
        "last_sync_timestamp": "",
        "databricks_target_table": dbx_target,
        "column_list": ", ".join(col_names),
        "primary_key_column": pk,
        "phantom_row_sql": phantom_sql,
    })

config_df = pl.DataFrame(config_rows)
print(f"\n✓ Generated {len(config_rows)} config entries")
config_df.select("sync_table_name", "primary_key_column")
# Out:
# Fetched 436 column definitions across 25 tables
#
# ✓ Generated 25 config entries
# shape: (25, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ sync_table_name                 ┆ primary_key_column              │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ midas_annualplans               ┆ midas_annualplanid              │
# │ midas_basemetrics               ┆ midas_basemetricid              │
# │ midas_dataflows                 ┆ midas_dataflowid                │
# │ midas_dataflowdependencys       ┆ midas_dataflowdependencyid      │
# │ midas_eedrillingprojectlocatio… ┆ midas_eedrillingprojectlocatio… │
# │ …                               ┆ …                               │
# │ gmr_basemeasuremappings         ┆ gmr_basemeasuremappingid        │
# │ gmr_metrics                     ┆ gmr_metricid                    │
# │ gmr_metricmappings              ┆ gmr_metricmappingid             │
# │ gmr_metriccategorys             ┆ gmr_metriccategoryid            │
# │ gmr_environments                ┆ gmr_environmentid               │
# └─────────────────────────────────┴─────────────────────────────────┘

# %%
# ─── Print each config entry in a readable format ─────────────────────────────
pl.Config.set_tbl_cols(10)
pl.Config.set_fmt_str_lengths(200)
pl.Config.set_tbl_width_chars(300)

for row in config_df.iter_rows(named=True):
    print(row["sync_table_name"])
    print()
    print(row["last_sync_timestamp"] or "(set at runtime)")
    print()
    print(row["databricks_target_table"])
    print()
    print(row["column_list"])
    print()
    print(row["primary_key_column"])
    print()
    print(row["phantom_row_sql"])
    print()
    print("─" * 120)
    print()
# Out:
# midas_annualplans
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_annualplan
#
# createdon, midas_annualplan, midas_annualplanid, midas_effectivedatefrom, midas_environment, midas_planmonth, midas_plannamenew, midas_plannedvalue, midas_plansource, midas_sitecode, modifiedon, statecode
#
# midas_annualplanid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_annualplan, CAST(NULL AS STRING) AS midas_annualplanid, CAST(NULL AS TIMESTAMP) AS midas_effectivedatefrom, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS TIMESTAMP) AS midas_planmonth, CAST(NULL AS STRING) AS midas_plannamenew, CAST(NULL AS DECIMAL(38,18)) AS midas_plannedvalue, CAST(NULL AS STRING) AS midas_plansource, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_basemetrics
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_basemetric
#
# createdon, midas_aoperandaggregation, midas_aoperandfact, midas_aoperandfactname, midas_aoperandfacttable, midas_aoperandfacttablename, midas_aoperandfilter, midas_basemetricid, midas_boperandaggregation, midas_boperandfact, midas_boperandfactname, midas_boperandfacttable, midas_boperandfacttablename, midas_boperandfilter, midas_category, midas_code, midas_coperandaggregation, midas_coperandfact, midas_coperandfactname, midas_coperandfacttable, midas_coperandfacttablename, midas_coperandfilter, midas_datasources, midas_denominator, midas_denominatordescription, midas_denominatoruom, midas_description, midas_direction, midas_documentreferences, midas_doperandaggregation, midas_doperandfact, midas_doperandfactname, midas_doperandfacttable, midas_doperandfacttablename, midas_doperandfilter, midas_environment, midas_folder, midas_formatstring, midas_generationperiod, midas_globaldataownerdatasteward, midas_ishidden, midas_issnapshotmetric, midas_metricalternativename, midas_metriccalculation, midas_metricuom, midas_name, midas_numerator, midas_numeratordescription, midas_numeratoruom, midas_stringformat, modifiedon, statecode
#
# midas_basemetricid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_aoperandaggregation, CAST(NULL AS STRING) AS midas_aoperandfact, CAST(NULL AS STRING) AS midas_aoperandfactname, CAST(NULL AS STRING) AS midas_aoperandfacttable, CAST(NULL AS STRING) AS midas_aoperandfacttablename, CAST(NULL AS STRING) AS midas_aoperandfilter, CAST(NULL AS STRING) AS midas_basemetricid, CAST(NULL AS INT) AS midas_boperandaggregation, CAST(NULL AS STRING) AS midas_boperandfact, CAST(NULL AS STRING) AS midas_boperandfactname, CAST(NULL AS STRING) AS midas_boperandfacttable, CAST(NULL AS STRING) AS midas_boperandfacttablename, CAST(NULL AS STRING) AS midas_boperandfilter, CAST(NULL AS INT) AS midas_category, CAST(NULL AS STRING) AS midas_code, CAST(NULL AS INT) AS midas_coperandaggregation, CAST(NULL AS STRING) AS midas_coperandfact, CAST(NULL AS STRING) AS midas_coperandfactname, CAST(NULL AS STRING) AS midas_coperandfacttable, CAST(NULL AS STRING) AS midas_coperandfacttablename, CAST(NULL AS STRING) AS midas_coperandfilter, CAST(NULL AS STRING) AS midas_datasources, CAST(NULL AS STRING) AS midas_denominator, CAST(NULL AS STRING) AS midas_denominatordescription, CAST(NULL AS INT) AS midas_denominatoruom, CAST(NULL AS STRING) AS midas_description, CAST(NULL AS BOOLEAN) AS midas_direction, CAST(NULL AS STRING) AS midas_documentreferences, CAST(NULL AS INT) AS midas_doperandaggregation, CAST(NULL AS STRING) AS midas_doperandfact, CAST(NULL AS STRING) AS midas_doperandfactname, CAST(NULL AS STRING) AS midas_doperandfacttable, CAST(NULL AS STRING) AS midas_doperandfacttablename, CAST(NULL AS STRING) AS midas_doperandfilter, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_folder, CAST(NULL AS STRING) AS midas_formatstring, CAST(NULL AS INT) AS midas_generationperiod, CAST(NULL AS STRING) AS midas_globaldataownerdatasteward, CAST(NULL AS BOOLEAN) AS midas_ishidden, CAST(NULL AS BOOLEAN) AS midas_issnapshotmetric, CAST(NULL AS STRING) AS midas_metricalternativename, CAST(NULL AS STRING) AS midas_metriccalculation, CAST(NULL AS INT) AS midas_metricuom, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_numerator, CAST(NULL AS STRING) AS midas_numeratordescription, CAST(NULL AS INT) AS midas_numeratoruom, CAST(NULL AS INT) AS midas_stringformat, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_dataflows
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_dataflow
#
# createdon, midas_dataflowid, midas_environment, midas_floworder, midas_name, midas_pattern, midas_sinkschema, midas_sinktable, midas_sourcedatecolumn, midas_sourcekeycolumns, midas_sourcequery, midas_sourceschema, midas_sourcetable, modifiedon, statecode
#
# midas_dataflowid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_dataflowid, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS INT) AS midas_floworder, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS INT) AS midas_pattern, CAST(NULL AS STRING) AS midas_sinkschema, CAST(NULL AS STRING) AS midas_sinktable, CAST(NULL AS STRING) AS midas_sourcedatecolumn, CAST(NULL AS STRING) AS midas_sourcekeycolumns, CAST(NULL AS STRING) AS midas_sourcequery, CAST(NULL AS STRING) AS midas_sourceschema, CAST(NULL AS STRING) AS midas_sourcetable, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_dataflowdependencys
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_dataflowdependency
#
# createdon, midas_dataflow, midas_dataflowdependencyid, midas_dataflowname, midas_dependson, midas_dependsonname, midas_name, modifiedon, statecode
#
# midas_dataflowdependencyid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_dataflow, CAST(NULL AS STRING) AS midas_dataflowdependencyid, CAST(NULL AS STRING) AS midas_dataflowname, CAST(NULL AS STRING) AS midas_dependson, CAST(NULL AS STRING) AS midas_dependsonname, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_eedrillingprojectlocationss
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_eedrillingprojectlocations
#
# createdon, midas_code, midas_eedrillingprojectlocationsid, midas_hub, midas_hubname, midas_projectname, midas_sourcename, modifiedon, statecode
#
# midas_eedrillingprojectlocationsid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_code, CAST(NULL AS STRING) AS midas_eedrillingprojectlocationsid, CAST(NULL AS STRING) AS midas_hub, CAST(NULL AS STRING) AS midas_hubname, CAST(NULL AS STRING) AS midas_projectname, CAST(NULL AS STRING) AS midas_sourcename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_eedrillingprojectlocationspatterns
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_eedrillingprojectlocationspattern
#
# createdon, midas_country, midas_districtstream, midas_eedrillingprojectlocationspatternid, midas_eeglobal, midas_region, midas_stataprovinceterritory, modifiedon, statecode
#
# midas_eedrillingprojectlocationspatternid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_country, CAST(NULL AS STRING) AS midas_districtstream, CAST(NULL AS STRING) AS midas_eedrillingprojectlocationspatternid, CAST(NULL AS INT) AS midas_eeglobal, CAST(NULL AS INT) AS midas_region, CAST(NULL AS STRING) AS midas_stataprovinceterritory, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_expitmovementactuals
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_expitmovementactual
#
# createdon, midas_environment, midas_expitmovementactual, midas_expitmovementactualid, midas_month, midas_name, midas_plantname, midas_sitecode, modifiedon, statecode
#
# midas_expitmovementactualid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS DECIMAL(38,18)) AS midas_expitmovementactual, CAST(NULL AS STRING) AS midas_expitmovementactualid, CAST(NULL AS TIMESTAMP) AS midas_month, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_plantname, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_fixedplantmetricmappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_fixedplantmetricmapping
#
# createdon, midas_effectivefrom, midas_environment, midas_fixedplantassetcode, midas_fixedplantmetricmappingid, midas_metrictype, midas_metricvalue, midas_name, midas_sitecode, modifiedon, statecode
#
# midas_fixedplantmetricmappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS TIMESTAMP) AS midas_effectivefrom, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_fixedplantassetcode, CAST(NULL AS STRING) AS midas_fixedplantmetricmappingid, CAST(NULL AS STRING) AS midas_metrictype, CAST(NULL AS STRING) AS midas_metricvalue, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_hmeassetactivitytypes
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_hmeassetactivitytype
#
# createdon, midas_activitytype, midas_assetcode, midas_automaticcontrol, midas_effectivefrom, midas_environment, midas_hmeassetactivitytypeid, midas_sapsitecode, modifiedon, statecode
#
# midas_hmeassetactivitytypeid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_activitytype, CAST(NULL AS STRING) AS midas_assetcode, CAST(NULL AS STRING) AS midas_automaticcontrol, CAST(NULL AS STRING) AS midas_effectivefrom, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_hmeassetactivitytypeid, CAST(NULL AS STRING) AS midas_sapsitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_hmeassetmappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_hmeassetmapping
#
# createdon, midas_abckz, midas_assettag, midas_eartx, midas_environment, midas_equart, midas_herst, midas_hiretytpe, midas_hmeassetmappingid, midas_instrumented, midas_maintainedbyrio, midas_mapsystem, midas_name1, midas_pltxt, midas_reportingfleet, midas_reportingmodel, midas_sitecode, midas_strno, midas_swerk, midas_system, midas_system_site, midas_tplnr, midas_txt04, midas_typbz, midas_zz_prod_unit, modifiedon, statecode
#
# midas_hmeassetmappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_abckz, CAST(NULL AS STRING) AS midas_assettag, CAST(NULL AS STRING) AS midas_eartx, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_equart, CAST(NULL AS STRING) AS midas_herst, CAST(NULL AS STRING) AS midas_hiretytpe, CAST(NULL AS STRING) AS midas_hmeassetmappingid, CAST(NULL AS STRING) AS midas_instrumented, CAST(NULL AS STRING) AS midas_maintainedbyrio, CAST(NULL AS STRING) AS midas_mapsystem, CAST(NULL AS STRING) AS midas_name1, CAST(NULL AS STRING) AS midas_pltxt, CAST(NULL AS STRING) AS midas_reportingfleet, CAST(NULL AS STRING) AS midas_reportingmodel, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_strno, CAST(NULL AS STRING) AS midas_swerk, CAST(NULL AS STRING) AS midas_system, CAST(NULL AS STRING) AS midas_system_site, CAST(NULL AS STRING) AS midas_tplnr, CAST(NULL AS STRING) AS midas_txt04, CAST(NULL AS STRING) AS midas_typbz, CAST(NULL AS STRING) AS midas_zz_prod_unit, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_hmetummappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_hmetummapping
#
# createdon, midas_environment, midas_hmetummappingid, midas_site, midas_tum5code, midas_tum5localcode, midas_tum5localname, midas_tum6code, midas_tum6localcode, midas_tum6localname, midas_tum6name, midas_tum7code, midas_tum7localcode, midas_tum7localname, midas_tum7name, modifiedon, statecode
#
# midas_hmetummappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_hmetummappingid, CAST(NULL AS STRING) AS midas_site, CAST(NULL AS STRING) AS midas_tum5code, CAST(NULL AS STRING) AS midas_tum5localcode, CAST(NULL AS STRING) AS midas_tum5localname, CAST(NULL AS STRING) AS midas_tum6code, CAST(NULL AS STRING) AS midas_tum6localcode, CAST(NULL AS STRING) AS midas_tum6localname, CAST(NULL AS STRING) AS midas_tum6name, CAST(NULL AS STRING) AS midas_tum7code, CAST(NULL AS STRING) AS midas_tum7localcode, CAST(NULL AS STRING) AS midas_tum7localname, CAST(NULL AS STRING) AS midas_tum7name, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_manualbasemetricss
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_manualbasemetrics
#
# createdon, midas_basemetric, midas_basemetricname, midas_denominator, midas_environment, midas_manualbasemetricsid, midas_metricdate, midas_name, midas_numerator, midas_site, midas_sitename, modifiedon, statecode
#
# midas_manualbasemetricsid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_basemetric, CAST(NULL AS STRING) AS midas_basemetricname, CAST(NULL AS DOUBLE) AS midas_denominator, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_manualbasemetricsid, CAST(NULL AS TIMESTAMP) AS midas_metricdate, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS DOUBLE) AS midas_numerator, CAST(NULL AS STRING) AS midas_site, CAST(NULL AS STRING) AS midas_sitename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_mdrs
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_mdr
#
# createdon, midas_assetcode, midas_assetname, midas_commodity, midas_effectivefromdate, midas_elementattribute, midas_environment, midas_mdrid, midas_mdrvalue, midas_name, midas_periodicity, midas_productgroup, midas_sitecode, midas_sitecodename, midas_type, midas_uom, midas_version, modifiedon, statecode
#
# midas_mdrid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_assetcode, CAST(NULL AS STRING) AS midas_assetname, CAST(NULL AS INT) AS midas_commodity, CAST(NULL AS TIMESTAMP) AS midas_effectivefromdate, CAST(NULL AS STRING) AS midas_elementattribute, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_mdrid, CAST(NULL AS DECIMAL(38,18)) AS midas_mdrvalue, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS INT) AS midas_periodicity, CAST(NULL AS INT) AS midas_productgroup, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_sitecodename, CAST(NULL AS INT) AS midas_type, CAST(NULL AS INT) AS midas_uom, CAST(NULL AS INT) AS midas_version, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_primegreatersitess
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_primegreatersites
#
# createdon, midas_businessunitname, midas_comment, midas_environment, midas_isactiveinprime, midas_primegreatersitecode, midas_primegreatersitename, midas_primegreatersitesid, midas_productgroupname, midas_sitecode, midas_sitename, modifiedon, statecode
#
# midas_primegreatersitesid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_businessunitname, CAST(NULL AS STRING) AS midas_comment, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS BOOLEAN) AS midas_isactiveinprime, CAST(NULL AS STRING) AS midas_primegreatersitecode, CAST(NULL AS STRING) AS midas_primegreatersitename, CAST(NULL AS STRING) AS midas_primegreatersitesid, CAST(NULL AS STRING) AS midas_productgroupname, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_sitename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_publicholidays
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_publicholiday
#
# createdon, midas_datekey, midas_environment, midas_name, midas_publicholidayid, modifiedon, statecode
#
# midas_publicholidayid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS TIMESTAMP) AS midas_datekey, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_publicholidayid, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_recoverys
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_recovery
#
# createdon, midas_assetcode, midas_assetname, midas_code, midas_commodity, midas_effectivefromdate, midas_environment, midas_productgroup, midas_recoveryid, midas_sitecode, midas_sitecodename, midas_type, midas_uom, midas_value, modifiedon, statecode
#
# midas_recoveryid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_assetcode, CAST(NULL AS STRING) AS midas_assetname, CAST(NULL AS STRING) AS midas_code, CAST(NULL AS INT) AS midas_commodity, CAST(NULL AS TIMESTAMP) AS midas_effectivefromdate, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS INT) AS midas_productgroup, CAST(NULL AS STRING) AS midas_recoveryid, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_sitecodename, CAST(NULL AS INT) AS midas_type, CAST(NULL AS STRING) AS midas_uom, CAST(NULL AS DECIMAL(38,18)) AS midas_value, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_sitemappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_sitemapping
#
# createdon, midas_effectivefromdate, midas_effectivetodate, midas_environment, midas_name, midas_opresplevelcode, midas_oucode, midas_sapoprespcode, midas_sapsitecode, midas_sitemappingid, midas_sourcesitecode, midas_sourcesystem, midas_unitysitecode, modifiedon, statecode
#
# midas_sitemappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS TIMESTAMP) AS midas_effectivefromdate, CAST(NULL AS TIMESTAMP) AS midas_effectivetodate, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS INT) AS midas_opresplevelcode, CAST(NULL AS STRING) AS midas_oucode, CAST(NULL AS STRING) AS midas_sapoprespcode, CAST(NULL AS STRING) AS midas_sapsitecode, CAST(NULL AS STRING) AS midas_sitemappingid, CAST(NULL AS STRING) AS midas_sourcesitecode, CAST(NULL AS INT) AS midas_sourcesystem, CAST(NULL AS STRING) AS midas_unitysitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_sourcetables
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_sourcetable
#
# createdon, midas_idpschema, midas_idptable, midas_monitor, midas_priority, midas_source, midas_sourcetableid, midas_udlextractor, midas_udlview, modifiedon, statecode
#
# midas_sourcetableid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_idpschema, CAST(NULL AS STRING) AS midas_idptable, CAST(NULL AS BOOLEAN) AS midas_monitor, CAST(NULL AS INT) AS midas_priority, CAST(NULL AS STRING) AS midas_source, CAST(NULL AS STRING) AS midas_sourcetableid, CAST(NULL AS STRING) AS midas_udlextractor, CAST(NULL AS STRING) AS midas_udlview, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_spatialconformances
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_spatialconformance
#
# createdon, midas_actualminedtoplanintonnes, midas_environment, midas_expitplannedminedintonnes, midas_materialflag, midas_month, midas_name, midas_sitecode, midas_sitename, midas_spatialconformanceid, midas_totalminedexpitmmintonnes, modifiedon, statecode
#
# midas_spatialconformanceid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS DECIMAL(38,18)) AS midas_actualminedtoplanintonnes, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS DECIMAL(38,18)) AS midas_expitplannedminedintonnes, CAST(NULL AS INT) AS midas_materialflag, CAST(NULL AS TIMESTAMP) AS midas_month, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_sitename, CAST(NULL AS STRING) AS midas_spatialconformanceid, CAST(NULL AS DECIMAL(38,18)) AS midas_totalminedexpitmmintonnes, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# gmr_basemeasures
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.gmr_basemeasure
#
# createdon, gmr_aggregationfunction, gmr_basemeasureid, gmr_category, gmr_categoryname, gmr_columnname, gmr_datasources, gmr_datasteward, gmr_description, gmr_documentreferences, gmr_folder, gmr_format, gmr_globaldataowner, gmr_metriccalculation, gmr_name, gmr_originatingenvironment, gmr_originatingenvironmentname, gmr_tablename, modifiedon, statecode
#
# gmr_basemeasureid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS gmr_aggregationfunction, CAST(NULL AS STRING) AS gmr_basemeasureid, CAST(NULL AS STRING) AS gmr_category, CAST(NULL AS STRING) AS gmr_categoryname, CAST(NULL AS STRING) AS gmr_columnname, CAST(NULL AS STRING) AS gmr_datasources, CAST(NULL AS STRING) AS gmr_datasteward, CAST(NULL AS STRING) AS gmr_description, CAST(NULL AS STRING) AS gmr_documentreferences, CAST(NULL AS STRING) AS gmr_folder, CAST(NULL AS INT) AS gmr_format, CAST(NULL AS STRING) AS gmr_globaldataowner, CAST(NULL AS STRING) AS gmr_metriccalculation, CAST(NULL AS STRING) AS gmr_name, CAST(NULL AS STRING) AS gmr_originatingenvironment, CAST(NULL AS STRING) AS gmr_originatingenvironmentname, CAST(NULL AS STRING) AS gmr_tablename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# gmr_basemeasuremappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.gmr_basemeasuremapping
#
# createdon, gmr_alternativename, gmr_basemeasure, gmr_basemeasuremappingid, gmr_basemeasurename, gmr_categoryalt, gmr_categoryaltname, gmr_columnnamealt, gmr_descriptionalt, gmr_environment, gmr_environmentname, gmr_folderalt, gmr_formatalt, gmr_ishidden, gmr_mappedname, gmr_shortname, gmr_tablenamealt, modifiedon, statecode
#
# gmr_basemeasuremappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS gmr_alternativename, CAST(NULL AS STRING) AS gmr_basemeasure, CAST(NULL AS STRING) AS gmr_basemeasuremappingid, CAST(NULL AS STRING) AS gmr_basemeasurename, CAST(NULL AS STRING) AS gmr_categoryalt, CAST(NULL AS STRING) AS gmr_categoryaltname, CAST(NULL AS STRING) AS gmr_columnnamealt, CAST(NULL AS STRING) AS gmr_descriptionalt, CAST(NULL AS STRING) AS gmr_environment, CAST(NULL AS STRING) AS gmr_environmentname, CAST(NULL AS STRING) AS gmr_folderalt, CAST(NULL AS STRING) AS gmr_formatalt, CAST(NULL AS BOOLEAN) AS gmr_ishidden, CAST(NULL AS STRING) AS gmr_mappedname, CAST(NULL AS STRING) AS gmr_shortname, CAST(NULL AS STRING) AS gmr_tablenamealt, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# gmr_metrics
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.gmr_metric
#
# createdon, gmr_category, gmr_categoryname, gmr_datasources, gmr_datasteward, gmr_daxformula, gmr_denominator, gmr_denominatordax, gmr_denominatordescription, gmr_description, gmr_direction, gmr_documentreferences, gmr_folder, gmr_format, gmr_globaldataowner, gmr_globaldataownerdatasteward, gmr_metriccalculation, gmr_metricid, gmr_name, gmr_nullaszero, gmr_numerator, gmr_numeratordax, gmr_numeratordescription, gmr_operandabasemeasure, gmr_operandabasemeasurename, gmr_operandafilter, gmr_operandametric, gmr_operandametricname, gmr_operandbbasemeasure, gmr_operandbbasemeasurename, gmr_operandbfilter, gmr_operandbmetric, gmr_operandbmetricname, gmr_operandcbasemeasure, gmr_operandcbasemeasurename, gmr_operandcfilter, gmr_operandcmetric, gmr_operandcmetricname, gmr_operanddbasemeasure, gmr_operanddbasemeasurename, gmr_operanddfilter, gmr_operanddmetric, gmr_operanddmetricname, gmr_operandebasemeasure, gmr_operandebasemeasurename, gmr_operandefilter, gmr_operandemetric, gmr_operandemetricname, gmr_operandfbasemeasure, gmr_operandfbasemeasurename, gmr_operandffilter, gmr_operandfmetric, gmr_operandfmetricname, gmr_originatingenvironment, gmr_originatingenvironmentname, gmr_uselastvaluea, gmr_uselastvalueb, gmr_uselastvaluec, gmr_uselastvalued, gmr_uselastvaluee, gmr_uselastvaluef, gmr_variationa, gmr_variationb, gmr_variationc, gmr_variationd, gmr_variatione, gmr_variationf, modifiedon, statecode
#
# gmr_metricid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS gmr_category, CAST(NULL AS STRING) AS gmr_categoryname, CAST(NULL AS STRING) AS gmr_datasources, CAST(NULL AS STRING) AS gmr_datasteward, CAST(NULL AS STRING) AS gmr_daxformula, CAST(NULL AS STRING) AS gmr_denominator, CAST(NULL AS STRING) AS gmr_denominatordax, CAST(NULL AS STRING) AS gmr_denominatordescription, CAST(NULL AS STRING) AS gmr_description, CAST(NULL AS BOOLEAN) AS gmr_direction, CAST(NULL AS STRING) AS gmr_documentreferences, CAST(NULL AS STRING) AS gmr_folder, CAST(NULL AS INT) AS gmr_format, CAST(NULL AS STRING) AS gmr_globaldataowner, CAST(NULL AS STRING) AS gmr_globaldataownerdatasteward, CAST(NULL AS STRING) AS gmr_metriccalculation, CAST(NULL AS STRING) AS gmr_metricid, CAST(NULL AS STRING) AS gmr_name, CAST(NULL AS BOOLEAN) AS gmr_nullaszero, CAST(NULL AS STRING) AS gmr_numerator, CAST(NULL AS STRING) AS gmr_numeratordax, CAST(NULL AS STRING) AS gmr_numeratordescription, CAST(NULL AS STRING) AS gmr_operandabasemeasure, CAST(NULL AS STRING) AS gmr_operandabasemeasurename, CAST(NULL AS STRING) AS gmr_operandafilter, CAST(NULL AS STRING) AS gmr_operandametric, CAST(NULL AS STRING) AS gmr_operandametricname, CAST(NULL AS STRING) AS gmr_operandbbasemeasure, CAST(NULL AS STRING) AS gmr_operandbbasemeasurename, CAST(NULL AS STRING) AS gmr_operandbfilter, CAST(NULL AS STRING) AS gmr_operandbmetric, CAST(NULL AS STRING) AS gmr_operandbmetricname, CAST(NULL AS STRING) AS gmr_operandcbasemeasure, CAST(NULL AS STRING) AS gmr_operandcbasemeasurename, CAST(NULL AS STRING) AS gmr_operandcfilter, CAST(NULL AS STRING) AS gmr_operandcmetric, CAST(NULL AS STRING) AS gmr_operandcmetricname, CAST(NULL AS STRING) AS gmr_operanddbasemeasure, CAST(NULL AS STRING) AS gmr_operanddbasemeasurename, CAST(NULL AS STRING) AS gmr_operanddfilter, CAST(NULL AS STRING) AS gmr_operanddmetric, CAST(NULL AS STRING) AS gmr_operanddmetricname, CAST(NULL AS STRING) AS gmr_operandebasemeasure, CAST(NULL AS STRING) AS gmr_operandebasemeasurename, CAST(NULL AS STRING) AS gmr_operandefilter, CAST(NULL AS STRING) AS gmr_operandemetric, CAST(NULL AS STRING) AS gmr_operandemetricname, CAST(NULL AS STRING) AS gmr_operandfbasemeasure, CAST(NULL AS STRING) AS gmr_operandfbasemeasurename, CAST(NULL AS STRING) AS gmr_operandffilter, CAST(NULL AS STRING) AS gmr_operandfmetric, CAST(NULL AS STRING) AS gmr_operandfmetricname, CAST(NULL AS STRING) AS gmr_originatingenvironment, CAST(NULL AS STRING) AS gmr_originatingenvironmentname, CAST(NULL AS BOOLEAN) AS gmr_uselastvaluea, CAST(NULL AS BOOLEAN) AS gmr_uselastvalueb, CAST(NULL AS BOOLEAN) AS gmr_uselastvaluec, CAST(NULL AS BOOLEAN) AS gmr_uselastvalued, CAST(NULL AS BOOLEAN) AS gmr_uselastvaluee, CAST(NULL AS BOOLEAN) AS gmr_uselastvaluef, CAST(NULL AS INT) AS gmr_variationa, CAST(NULL AS INT) AS gmr_variationb, CAST(NULL AS INT) AS gmr_variationc, CAST(NULL AS INT) AS gmr_variationd, CAST(NULL AS INT) AS gmr_variatione, CAST(NULL AS INT) AS gmr_variationf, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# gmr_metricmappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.gmr_metricmapping
#
# createdon, gmr_alternativename, gmr_categoryalt, gmr_categoryaltname, gmr_daxformulaalt, gmr_denominatordaxalt, gmr_descriptionalt, gmr_environment, gmr_environmentname, gmr_folderalt, gmr_formatalt, gmr_ishidden, gmr_mappedname, gmr_metric, gmr_metricmappingid, gmr_metricname, gmr_numeratordaxalt, gmr_shortname, modifiedon, statecode
#
# gmr_metricmappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS gmr_alternativename, CAST(NULL AS STRING) AS gmr_categoryalt, CAST(NULL AS STRING) AS gmr_categoryaltname, CAST(NULL AS STRING) AS gmr_daxformulaalt, CAST(NULL AS STRING) AS gmr_denominatordaxalt, CAST(NULL AS STRING) AS gmr_descriptionalt, CAST(NULL AS STRING) AS gmr_environment, CAST(NULL AS STRING) AS gmr_environmentname, CAST(NULL AS STRING) AS gmr_folderalt, CAST(NULL AS STRING) AS gmr_formatalt, CAST(NULL AS BOOLEAN) AS gmr_ishidden, CAST(NULL AS STRING) AS gmr_mappedname, CAST(NULL AS STRING) AS gmr_metric, CAST(NULL AS STRING) AS gmr_metricmappingid, CAST(NULL AS STRING) AS gmr_metricname, CAST(NULL AS STRING) AS gmr_numeratordaxalt, CAST(NULL AS STRING) AS gmr_shortname, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# gmr_metriccategorys
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.gmr_metriccategory
#
# createdon, gmr_metriccategoryid, gmr_name, modifiedon, statecode
#
# gmr_metriccategoryid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS gmr_metriccategoryid, CAST(NULL AS STRING) AS gmr_name, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# gmr_environments
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.gmr_environment
#
# createdon, gmr_asdatabasename, gmr_asservername, gmr_astype, gmr_credentialname, gmr_environmentid, gmr_name, gmr_pbidatasetid, gmr_pbidatasetname, gmr_pbidsappid, gmr_pbidstenantid, gmr_pbidsworkspaceurl, gmr_pipelinesecret, modifiedon, statecode
#
# gmr_environmentid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS gmr_asdatabasename, CAST(NULL AS STRING) AS gmr_asservername, CAST(NULL AS INT) AS gmr_astype, CAST(NULL AS STRING) AS gmr_credentialname, CAST(NULL AS STRING) AS gmr_environmentid, CAST(NULL AS STRING) AS gmr_name, CAST(NULL AS STRING) AS gmr_pbidatasetid, CAST(NULL AS STRING) AS gmr_pbidatasetname, CAST(NULL AS STRING) AS gmr_pbidsappid, CAST(NULL AS STRING) AS gmr_pbidstenantid, CAST(NULL AS STRING) AS gmr_pbidsworkspaceurl, CAST(NULL AS STRING) AS gmr_pipelinesecret, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# ─── Export to Excel (optional) ──────────────────────────────────────────────────
output_path = "sync_config_table.xlsx"
config_df.write_excel(output_path)
print(f"✓ Exported to {output_path}")
# Out:
# ✓ Exported to sync_config_table.xlsx

# %% [markdown]
# ## Rebuild Config from Dataverse API
# Connect directly to Dataverse to get the correct **EntitySetName** (sync_table_name) and attribute types for each entity, then cross-reference with the Synapse column list for precision.

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# ─── Authenticate to Dataverse ─────────────────────────────────────────────────
dataverse_url = "https://rt-citizen-prime-prd-au.crm6.dynamics.com"
client_id     = "c249f153-f8f1-44c5-8c3b-5e7368635f8d"
tenant_id     = "4341df80-fbe6-41bf-89b0-e6e2379c9c23"
client_secret = os.environ["DATAVERSE_CLIENT_SECRET"]

token_resp = requests.post(
    f"https://login.microsoftonline.com/{tenant_id}/oauth2/v2.0/token",
    data={
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,
        "scope": f"{dataverse_url}/.default",
    },
)
token_resp.raise_for_status()
dv_token = token_resp.json()["access_token"]
print("✓ Authenticated to Dataverse")

dv_session = requests.Session()
dv_session.mount("https://", HTTPAdapter(max_retries=Retry(
    total=3, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET"],
)))
dv_headers = {
    "Authorization": f"Bearer {dv_token}",
    "Accept": "application/json",
    "OData-Version": "4.0",
    "OData-MaxVersion": "4.0",
}

# ─── Fetch all EntityDefinitions → EntitySetName lookup ────────────────────────
print("Fetching EntityDefinitions (may take a moment)...")
ent_resp = dv_session.get(
    f"{dataverse_url}/api/data/v9.2/EntityDefinitions",
    headers=dv_headers,
    timeout=(10, 120),
)
ent_resp.raise_for_status()
entity_set_map = {
    e["LogicalName"]: e.get("EntitySetName", e["LogicalName"] + "s")
    for e in ent_resp.json()["value"]
}
print(f"  Loaded {len(entity_set_map)} entity definitions")
# Out:
# ✓ Authenticated to Dataverse
# Fetching EntityDefinitions (may take a moment)...
#   Loaded 940 entity definitions

# %%
# ─── Dataverse AttributeType → Databricks SQL type ────────────────────────────
DV_TYPE_MAP = {
    "String": "STRING",
    "Memo": "STRING",
    "Integer": "INT",
    "BigInt": "BIGINT",
    "Decimal": "DECIMAL",       # precision filled from Synapse or default
    "Double": "DOUBLE",
    "Money": "DECIMAL",         # precision filled from Synapse or default
    "Boolean": "BOOLEAN",
    "DateTime": "TIMESTAMP",
    "Uniqueidentifier": "STRING",
    "Lookup": "STRING",
    "Customer": "STRING",
    "Owner": "STRING",
    "Picklist": "INT",
    "State": "INT",
    "Status": "INT",
    "EntityName": "STRING",
    "Image": "STRING",
    "File": "STRING",
    "MultiSelectPicklist": "STRING",
}

SKIP_ATTR_TYPES = {"Virtual", "ManagedProperty", "CalendarRules", "PartyList"}

# ─── Build config from Dataverse + Synapse precision ──────────────────────────
config_rows_dv = []
table_names = [t.split(".", 1)[1] for t in tables_to_migrate]

for table in table_names:
    entity_set_name = entity_set_map.get(table)
    if not entity_set_name:
        print(f"⚠ {table}: not found in Dataverse — skipped")
        continue

    # Fetch attributes for this entity
    attrs_resp = dv_session.get(
        f"{dataverse_url}/api/data/v9.2/"
        f"EntityDefinitions(LogicalName='{table}')/Attributes",
        headers=dv_headers,
        timeout=(10, 90),
    )
    attrs_resp.raise_for_status()
    raw_attrs = attrs_resp.json()["value"]

    # Synapse columns for this table (lowercase set for cross-reference)
    syn_cols_for_table = set(
        all_columns_df
        .filter(pl.col("TABLE_NAME") == table)["COLUMN_NAME"]
        .str.to_lowercase()
        .to_list()
    )

    # Filter & map attributes
    attrs = []
    for a in raw_attrs:
        attr_type = a.get("AttributeType", "")
        name = a.get("LogicalName", "")

        if attr_type in SKIP_ATTR_TYPES:
            continue

        # Only keep columns that exist in the Synapse MDE schema
        if syn_cols_for_table and name.lower() not in syn_cols_for_table:
            continue

        # Lookup/Customer/Owner attributes use _<logicalname>_value in Web API $select
        if attr_type in ("Lookup", "Customer", "Owner"):
            api_name = f"_{name}_value"
        else:
            api_name = name

        # Map to Databricks type
        dbx_type = DV_TYPE_MAP.get(attr_type, "STRING")

        # For Decimal/Money: pull precision from Synapse metadata
        if dbx_type == "DECIMAL":
            syn_row = all_columns_df.filter(
                (pl.col("TABLE_NAME") == table)
                & (pl.col("COLUMN_NAME").str.to_lowercase() == name.lower())
            )
            if syn_row.height > 0:
                p = syn_row["NUMERIC_PRECISION"][0]
                s = syn_row["NUMERIC_SCALE"][0]
                if p is not None:
                    dbx_type = f"DECIMAL({p},{s or 0})"
                else:
                    dbx_type = "DECIMAL(38,4)" if attr_type == "Money" else "DECIMAL(38,10)"
            else:
                dbx_type = "DECIMAL(38,4)" if attr_type == "Money" else "DECIMAL(38,10)"

        attrs.append({"name": api_name, "dbx_type": dbx_type})

    if not attrs:
        print(f"⚠ {table}: no matching columns — skipped")
        continue

    # Sort alphabetically (matching the example format)
    attrs.sort(key=lambda x: x["name"])
    col_names = [a["name"] for a in attrs]

    # Primary key — Dataverse convention: <tablename>id
    pk = f"{table}id"
    if pk not in col_names:
        id_cols = [c for c in col_names if c.endswith("id")]
        pk = id_cols[0] if id_cols else col_names[0]

    # Phantom row SQL
    cast_parts = [f"CAST(NULL AS {a['dbx_type']}) AS {a['name']}" for a in attrs]
    phantom_sql = "SELECT " + ", ".join(cast_parts) + " WHERE 1=0"

    dbx_target = f"{DBX_CATALOG}.{DBX_SCHEMA}.{table}"

    config_rows_dv.append({
        "sync_table_name": entity_set_name,
        "last_sync_timestamp": "",
        "databricks_target_table": dbx_target,
        "column_list": ", ".join(col_names),
        "primary_key_column": pk,
        "phantom_row_sql": phantom_sql,
    })


    print(f"✓ {table} → {entity_set_name} ({len(col_names)} cols, "
          f"{len(raw_attrs)} total in Dataverse)")

config_dv_df = pl.DataFrame(config_rows_dv)
print(f"\n✓ Generated {len(config_rows_dv)} config entries from Dataverse")
config_dv_df.select("sync_table_name", "primary_key_column")
# Out:
# ✓ midas_annualplan → midas_annualplans (12 cols, 41 total in Dataverse)
# ✓ midas_basemetric → midas_basemetrics (52 cols, 100 total in Dataverse)
# ✓ midas_dataflow → midas_dataflows (15 cols, 45 total in Dataverse)
# ✓ midas_dataflowdependency → midas_dataflowdependencies (9 cols, 37 total in Dataverse)
# ✓ midas_eedrillingprojectlocations → midas_eedrillingprojectlocationses (9 cols, 37 total in Dataverse)
# ✓ midas_eedrillingprojectlocationspattern → midas_eedrillingprojectlocationspatterns (9 cols, 40 total in Dataverse)
# ✓ midas_expitmovementactual → midas_expitmovementactuals (10 cols, 39 total in Dataverse)
# ✓ midas_fixedplantmetricmapping → midas_fixedplantmetricmappings (11 cols, 40 total in Dataverse)
# ✓ midas_hmeassetactivitytype → midas_hmeassetactivitytypes (10 cols, 39 total in Dataverse)
# ✓ midas_hmeassetmapping → midas_hmeassetmappings (27 cols, 56 total in Dataverse)
# ✓ midas_hmetummapping → midas_hmetummappings (17 cols, 46 total in Dataverse)
# ✓ midas_manualbasemetrics → midas_manualbasemetricses (13 cols, 42 total in Dataverse)
# ✓ midas_mdr → midas_mdrs (19 cols, 54 total in Dataverse)
# ✓ midas_primegreatersites → midas_primegreatersiteses (13 cols, 43 total in Dataverse)
# ✓ midas_publicholiday → midas_publicholidaies (7 cols, 36 total in Dataverse)
# ✓ midas_recovery → midas_recoveries (16 cols, 48 total in Dataverse)
# ✓ midas_sitemapping → midas_sitemappings (15 cols, 46 total in Dataverse)
# ✓ midas_sourcetable → midas_sourcetables (11 cols, 40 total in Dataverse)
# ✓ midas_spatialconformance → midas_spatialconformances (13 cols, 43 total in Dataverse)
# ⚠ gmr_basemeasure: not found in Dataverse — skipped
# ⚠ gmr_basemeasuremapping: not found in Dataverse — skipped
# ⚠ gmr_metric: not found in Dataverse — skipped
# ⚠ gmr_metricmapping: not found in Dataverse — skipped
# ⚠ gmr_metriccategory: not found in Dataverse — skipped
# ⚠ gmr_environment: not found in Dataverse — skipped
#
# ✓ Generated 19 config entries from Dataverse
# shape: (19, 2)
# ┌────────────────────────────────────┬────────────────────────────────────┐
# │ sync_table_name                    ┆ primary_key_column                 │
# │ ---                                ┆ ---                                │
# │ str                                ┆ str                                │
# ╞════════════════════════════════════╪════════════════════════════════════╡
# │ midas_annualplans                  ┆ midas_annualplanid                 │
# │ midas_basemetrics                  ┆ midas_basemetricid                 │
# │ midas_dataflows                    ┆ midas_dataflowid                   │
# │ midas_dataflowdependencies         ┆ midas_dataflowdependencyid         │
# │ midas_eedrillingprojectlocationses ┆ midas_eedrillingprojectlocationsid │
# │ …                                  ┆ …                                  │
# │ midas_publicholidaies              ┆ midas_publicholidayid              │
# │ midas_recoveries                   ┆ midas_recoveryid                   │
# │ midas_sitemappings                 ┆ midas_sitemappingid                │
# │ midas_sourcetables                 ┆ midas_sourcetableid                │
# │ midas_spatialconformances          ┆ midas_spatialconformanceid         │
# └────────────────────────────────────┴────────────────────────────────────┘

# %%
# ─── Print each Dataverse-sourced config entry ────────────────────────────────
for row in config_dv_df.iter_rows(named=True):
    print(row["sync_table_name"])
    print()
    print(row["last_sync_timestamp"] or "(set at runtime)")
    print()
    print(row["databricks_target_table"])
    print()
    print(row["column_list"])
    print()
    print(row["primary_key_column"])
    print()
    print(row["phantom_row_sql"])
    print()
    print("─" * 120)
    print()

# Export
config_dv_df.write_csv("sync_config_table_dataverse.csv")
print("✓ Exported to sync_config_table_dataverse.csv")
# Out:
# midas_annualplans
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_annualplan
#
# createdon, midas_annualplan, midas_annualplanid, midas_effectivedatefrom, midas_environment, midas_planmonth, midas_plannamenew, midas_plannedvalue, midas_plansource, midas_sitecode, modifiedon, statecode
#
# midas_annualplanid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_annualplan, CAST(NULL AS STRING) AS midas_annualplanid, CAST(NULL AS TIMESTAMP) AS midas_effectivedatefrom, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS TIMESTAMP) AS midas_planmonth, CAST(NULL AS STRING) AS midas_plannamenew, CAST(NULL AS DECIMAL(38,18)) AS midas_plannedvalue, CAST(NULL AS STRING) AS midas_plansource, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_basemetrics
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_basemetric
#
# _midas_aoperandfact_value, _midas_aoperandfacttable_value, _midas_boperandfact_value, _midas_boperandfacttable_value, _midas_coperandfact_value, _midas_coperandfacttable_value, _midas_doperandfact_value, _midas_doperandfacttable_value, createdon, midas_aoperandaggregation, midas_aoperandfactname, midas_aoperandfacttablename, midas_aoperandfilter, midas_basemetricid, midas_boperandaggregation, midas_boperandfactname, midas_boperandfacttablename, midas_boperandfilter, midas_category, midas_code, midas_coperandaggregation, midas_coperandfactname, midas_coperandfacttablename, midas_coperandfilter, midas_datasources, midas_denominator, midas_denominatordescription, midas_denominatoruom, midas_description, midas_direction, midas_documentreferences, midas_doperandaggregation, midas_doperandfactname, midas_doperandfacttablename, midas_doperandfilter, midas_environment, midas_folder, midas_formatstring, midas_generationperiod, midas_globaldataownerdatasteward, midas_ishidden, midas_issnapshotmetric, midas_metricalternativename, midas_metriccalculation, midas_metricuom, midas_name, midas_numerator, midas_numeratordescription, midas_numeratoruom, midas_stringformat, modifiedon, statecode
#
# midas_basemetricid
#
# SELECT CAST(NULL AS STRING) AS _midas_aoperandfact_value, CAST(NULL AS STRING) AS _midas_aoperandfacttable_value, CAST(NULL AS STRING) AS _midas_boperandfact_value, CAST(NULL AS STRING) AS _midas_boperandfacttable_value, CAST(NULL AS STRING) AS _midas_coperandfact_value, CAST(NULL AS STRING) AS _midas_coperandfacttable_value, CAST(NULL AS STRING) AS _midas_doperandfact_value, CAST(NULL AS STRING) AS _midas_doperandfacttable_value, CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_aoperandaggregation, CAST(NULL AS STRING) AS midas_aoperandfactname, CAST(NULL AS STRING) AS midas_aoperandfacttablename, CAST(NULL AS STRING) AS midas_aoperandfilter, CAST(NULL AS STRING) AS midas_basemetricid, CAST(NULL AS INT) AS midas_boperandaggregation, CAST(NULL AS STRING) AS midas_boperandfactname, CAST(NULL AS STRING) AS midas_boperandfacttablename, CAST(NULL AS STRING) AS midas_boperandfilter, CAST(NULL AS INT) AS midas_category, CAST(NULL AS STRING) AS midas_code, CAST(NULL AS INT) AS midas_coperandaggregation, CAST(NULL AS STRING) AS midas_coperandfactname, CAST(NULL AS STRING) AS midas_coperandfacttablename, CAST(NULL AS STRING) AS midas_coperandfilter, CAST(NULL AS STRING) AS midas_datasources, CAST(NULL AS STRING) AS midas_denominator, CAST(NULL AS STRING) AS midas_denominatordescription, CAST(NULL AS INT) AS midas_denominatoruom, CAST(NULL AS STRING) AS midas_description, CAST(NULL AS BOOLEAN) AS midas_direction, CAST(NULL AS STRING) AS midas_documentreferences, CAST(NULL AS INT) AS midas_doperandaggregation, CAST(NULL AS STRING) AS midas_doperandfactname, CAST(NULL AS STRING) AS midas_doperandfacttablename, CAST(NULL AS STRING) AS midas_doperandfilter, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_folder, CAST(NULL AS STRING) AS midas_formatstring, CAST(NULL AS INT) AS midas_generationperiod, CAST(NULL AS STRING) AS midas_globaldataownerdatasteward, CAST(NULL AS BOOLEAN) AS midas_ishidden, CAST(NULL AS BOOLEAN) AS midas_issnapshotmetric, CAST(NULL AS STRING) AS midas_metricalternativename, CAST(NULL AS STRING) AS midas_metriccalculation, CAST(NULL AS INT) AS midas_metricuom, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_numerator, CAST(NULL AS STRING) AS midas_numeratordescription, CAST(NULL AS INT) AS midas_numeratoruom, CAST(NULL AS INT) AS midas_stringformat, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_dataflows
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_dataflow
#
# createdon, midas_dataflowid, midas_environment, midas_floworder, midas_name, midas_pattern, midas_sinkschema, midas_sinktable, midas_sourcedatecolumn, midas_sourcekeycolumns, midas_sourcequery, midas_sourceschema, midas_sourcetable, modifiedon, statecode
#
# midas_dataflowid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_dataflowid, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS INT) AS midas_floworder, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS INT) AS midas_pattern, CAST(NULL AS STRING) AS midas_sinkschema, CAST(NULL AS STRING) AS midas_sinktable, CAST(NULL AS STRING) AS midas_sourcedatecolumn, CAST(NULL AS STRING) AS midas_sourcekeycolumns, CAST(NULL AS STRING) AS midas_sourcequery, CAST(NULL AS STRING) AS midas_sourceschema, CAST(NULL AS STRING) AS midas_sourcetable, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_dataflowdependencies
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_dataflowdependency
#
# _midas_dataflow_value, _midas_dependson_value, createdon, midas_dataflowdependencyid, midas_dataflowname, midas_dependsonname, midas_name, modifiedon, statecode
#
# midas_dataflowdependencyid
#
# SELECT CAST(NULL AS STRING) AS _midas_dataflow_value, CAST(NULL AS STRING) AS _midas_dependson_value, CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_dataflowdependencyid, CAST(NULL AS STRING) AS midas_dataflowname, CAST(NULL AS STRING) AS midas_dependsonname, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_eedrillingprojectlocationses
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_eedrillingprojectlocations
#
# _midas_hub_value, createdon, midas_code, midas_eedrillingprojectlocationsid, midas_hubname, midas_projectname, midas_sourcename, modifiedon, statecode
#
# midas_eedrillingprojectlocationsid
#
# SELECT CAST(NULL AS STRING) AS _midas_hub_value, CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_code, CAST(NULL AS STRING) AS midas_eedrillingprojectlocationsid, CAST(NULL AS STRING) AS midas_hubname, CAST(NULL AS STRING) AS midas_projectname, CAST(NULL AS STRING) AS midas_sourcename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_eedrillingprojectlocationspatterns
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_eedrillingprojectlocationspattern
#
# createdon, midas_country, midas_districtstream, midas_eedrillingprojectlocationspatternid, midas_eeglobal, midas_region, midas_stataprovinceterritory, modifiedon, statecode
#
# midas_eedrillingprojectlocationspatternid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_country, CAST(NULL AS STRING) AS midas_districtstream, CAST(NULL AS STRING) AS midas_eedrillingprojectlocationspatternid, CAST(NULL AS INT) AS midas_eeglobal, CAST(NULL AS INT) AS midas_region, CAST(NULL AS STRING) AS midas_stataprovinceterritory, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_expitmovementactuals
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_expitmovementactual
#
# createdon, midas_environment, midas_expitmovementactual, midas_expitmovementactualid, midas_month, midas_name, midas_plantname, midas_sitecode, modifiedon, statecode
#
# midas_expitmovementactualid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS DECIMAL(38,18)) AS midas_expitmovementactual, CAST(NULL AS STRING) AS midas_expitmovementactualid, CAST(NULL AS TIMESTAMP) AS midas_month, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_plantname, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_fixedplantmetricmappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_fixedplantmetricmapping
#
# createdon, midas_effectivefrom, midas_environment, midas_fixedplantassetcode, midas_fixedplantmetricmappingid, midas_metrictype, midas_metricvalue, midas_name, midas_sitecode, modifiedon, statecode
#
# midas_fixedplantmetricmappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS TIMESTAMP) AS midas_effectivefrom, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_fixedplantassetcode, CAST(NULL AS STRING) AS midas_fixedplantmetricmappingid, CAST(NULL AS STRING) AS midas_metrictype, CAST(NULL AS STRING) AS midas_metricvalue, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_hmeassetactivitytypes
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_hmeassetactivitytype
#
# createdon, midas_activitytype, midas_assetcode, midas_automaticcontrol, midas_effectivefrom, midas_environment, midas_hmeassetactivitytypeid, midas_sapsitecode, modifiedon, statecode
#
# midas_hmeassetactivitytypeid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_activitytype, CAST(NULL AS STRING) AS midas_assetcode, CAST(NULL AS STRING) AS midas_automaticcontrol, CAST(NULL AS STRING) AS midas_effectivefrom, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_hmeassetactivitytypeid, CAST(NULL AS STRING) AS midas_sapsitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_hmeassetmappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_hmeassetmapping
#
# createdon, midas_abckz, midas_assettag, midas_eartx, midas_environment, midas_equart, midas_herst, midas_hiretytpe, midas_hmeassetmappingid, midas_instrumented, midas_maintainedbyrio, midas_mapsystem, midas_name1, midas_pltxt, midas_reportingfleet, midas_reportingmodel, midas_sitecode, midas_strno, midas_swerk, midas_system, midas_system_site, midas_tplnr, midas_txt04, midas_typbz, midas_zz_prod_unit, modifiedon, statecode
#
# midas_hmeassetmappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_abckz, CAST(NULL AS STRING) AS midas_assettag, CAST(NULL AS STRING) AS midas_eartx, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_equart, CAST(NULL AS STRING) AS midas_herst, CAST(NULL AS STRING) AS midas_hiretytpe, CAST(NULL AS STRING) AS midas_hmeassetmappingid, CAST(NULL AS STRING) AS midas_instrumented, CAST(NULL AS STRING) AS midas_maintainedbyrio, CAST(NULL AS STRING) AS midas_mapsystem, CAST(NULL AS STRING) AS midas_name1, CAST(NULL AS STRING) AS midas_pltxt, CAST(NULL AS STRING) AS midas_reportingfleet, CAST(NULL AS STRING) AS midas_reportingmodel, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_strno, CAST(NULL AS STRING) AS midas_swerk, CAST(NULL AS STRING) AS midas_system, CAST(NULL AS STRING) AS midas_system_site, CAST(NULL AS STRING) AS midas_tplnr, CAST(NULL AS STRING) AS midas_txt04, CAST(NULL AS STRING) AS midas_typbz, CAST(NULL AS STRING) AS midas_zz_prod_unit, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_hmetummappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_hmetummapping
#
# createdon, midas_environment, midas_hmetummappingid, midas_site, midas_tum5code, midas_tum5localcode, midas_tum5localname, midas_tum6code, midas_tum6localcode, midas_tum6localname, midas_tum6name, midas_tum7code, midas_tum7localcode, midas_tum7localname, midas_tum7name, modifiedon, statecode
#
# midas_hmetummappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_hmetummappingid, CAST(NULL AS STRING) AS midas_site, CAST(NULL AS STRING) AS midas_tum5code, CAST(NULL AS STRING) AS midas_tum5localcode, CAST(NULL AS STRING) AS midas_tum5localname, CAST(NULL AS STRING) AS midas_tum6code, CAST(NULL AS STRING) AS midas_tum6localcode, CAST(NULL AS STRING) AS midas_tum6localname, CAST(NULL AS STRING) AS midas_tum6name, CAST(NULL AS STRING) AS midas_tum7code, CAST(NULL AS STRING) AS midas_tum7localcode, CAST(NULL AS STRING) AS midas_tum7localname, CAST(NULL AS STRING) AS midas_tum7name, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_manualbasemetricses
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_manualbasemetrics
#
# _midas_basemetric_value, _midas_site_value, createdon, midas_basemetricname, midas_denominator, midas_environment, midas_manualbasemetricsid, midas_metricdate, midas_name, midas_numerator, midas_sitename, modifiedon, statecode
#
# midas_manualbasemetricsid
#
# SELECT CAST(NULL AS STRING) AS _midas_basemetric_value, CAST(NULL AS STRING) AS _midas_site_value, CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_basemetricname, CAST(NULL AS DOUBLE) AS midas_denominator, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_manualbasemetricsid, CAST(NULL AS TIMESTAMP) AS midas_metricdate, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS DOUBLE) AS midas_numerator, CAST(NULL AS STRING) AS midas_sitename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_mdrs
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_mdr
#
# _midas_sitecode_value, createdon, midas_assetcode, midas_assetname, midas_commodity, midas_effectivefromdate, midas_elementattribute, midas_environment, midas_mdrid, midas_mdrvalue, midas_name, midas_periodicity, midas_productgroup, midas_sitecodename, midas_type, midas_uom, midas_version, modifiedon, statecode
#
# midas_mdrid
#
# SELECT CAST(NULL AS STRING) AS _midas_sitecode_value, CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_assetcode, CAST(NULL AS STRING) AS midas_assetname, CAST(NULL AS INT) AS midas_commodity, CAST(NULL AS TIMESTAMP) AS midas_effectivefromdate, CAST(NULL AS STRING) AS midas_elementattribute, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_mdrid, CAST(NULL AS DECIMAL(38,18)) AS midas_mdrvalue, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS INT) AS midas_periodicity, CAST(NULL AS INT) AS midas_productgroup, CAST(NULL AS STRING) AS midas_sitecodename, CAST(NULL AS INT) AS midas_type, CAST(NULL AS INT) AS midas_uom, CAST(NULL AS INT) AS midas_version, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_primegreatersiteses
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_primegreatersites
#
# createdon, midas_businessunitname, midas_comment, midas_environment, midas_isactiveinprime, midas_primegreatersitecode, midas_primegreatersitename, midas_primegreatersitesid, midas_productgroupname, midas_sitecode, midas_sitename, modifiedon, statecode
#
# midas_primegreatersitesid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_businessunitname, CAST(NULL AS STRING) AS midas_comment, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS BOOLEAN) AS midas_isactiveinprime, CAST(NULL AS STRING) AS midas_primegreatersitecode, CAST(NULL AS STRING) AS midas_primegreatersitename, CAST(NULL AS STRING) AS midas_primegreatersitesid, CAST(NULL AS STRING) AS midas_productgroupname, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_sitename, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_publicholidaies
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_publicholiday
#
# createdon, midas_datekey, midas_environment, midas_name, midas_publicholidayid, modifiedon, statecode
#
# midas_publicholidayid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS TIMESTAMP) AS midas_datekey, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_publicholidayid, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_recoveries
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_recovery
#
# _midas_sitecode_value, createdon, midas_assetcode, midas_assetname, midas_code, midas_commodity, midas_effectivefromdate, midas_environment, midas_productgroup, midas_recoveryid, midas_sitecodename, midas_type, midas_uom, midas_value, modifiedon, statecode
#
# midas_recoveryid
#
# SELECT CAST(NULL AS STRING) AS _midas_sitecode_value, CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_assetcode, CAST(NULL AS STRING) AS midas_assetname, CAST(NULL AS STRING) AS midas_code, CAST(NULL AS INT) AS midas_commodity, CAST(NULL AS TIMESTAMP) AS midas_effectivefromdate, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS INT) AS midas_productgroup, CAST(NULL AS STRING) AS midas_recoveryid, CAST(NULL AS STRING) AS midas_sitecodename, CAST(NULL AS INT) AS midas_type, CAST(NULL AS STRING) AS midas_uom, CAST(NULL AS DECIMAL(38,18)) AS midas_value, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_sitemappings
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_sitemapping
#
# createdon, midas_effectivefromdate, midas_effectivetodate, midas_environment, midas_name, midas_opresplevelcode, midas_oucode, midas_sapoprespcode, midas_sapsitecode, midas_sitemappingid, midas_sourcesitecode, midas_sourcesystem, midas_unitysitecode, modifiedon, statecode
#
# midas_sitemappingid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS TIMESTAMP) AS midas_effectivefromdate, CAST(NULL AS TIMESTAMP) AS midas_effectivetodate, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS INT) AS midas_opresplevelcode, CAST(NULL AS STRING) AS midas_oucode, CAST(NULL AS STRING) AS midas_sapoprespcode, CAST(NULL AS STRING) AS midas_sapsitecode, CAST(NULL AS STRING) AS midas_sitemappingid, CAST(NULL AS STRING) AS midas_sourcesitecode, CAST(NULL AS INT) AS midas_sourcesystem, CAST(NULL AS STRING) AS midas_unitysitecode, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_sourcetables
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_sourcetable
#
# createdon, midas_idpschema, midas_idptable, midas_monitor, midas_priority, midas_source, midas_sourcetableid, midas_udlextractor, midas_udlview, modifiedon, statecode
#
# midas_sourcetableid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS STRING) AS midas_idpschema, CAST(NULL AS STRING) AS midas_idptable, CAST(NULL AS BOOLEAN) AS midas_monitor, CAST(NULL AS INT) AS midas_priority, CAST(NULL AS STRING) AS midas_source, CAST(NULL AS STRING) AS midas_sourcetableid, CAST(NULL AS STRING) AS midas_udlextractor, CAST(NULL AS STRING) AS midas_udlview, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# midas_spatialconformances
#
# (set at runtime)
#
# _ogr_azr_syd_dev.mde.midas_spatialconformance
#
# createdon, midas_actualminedtoplanintonnes, midas_environment, midas_expitplannedminedintonnes, midas_materialflag, midas_month, midas_name, midas_sitecode, midas_sitename, midas_spatialconformanceid, midas_totalminedexpitmmintonnes, modifiedon, statecode
#
# midas_spatialconformanceid
#
# SELECT CAST(NULL AS TIMESTAMP) AS createdon, CAST(NULL AS DECIMAL(38,18)) AS midas_actualminedtoplanintonnes, CAST(NULL AS INT) AS midas_environment, CAST(NULL AS DECIMAL(38,18)) AS midas_expitplannedminedintonnes, CAST(NULL AS INT) AS midas_materialflag, CAST(NULL AS TIMESTAMP) AS midas_month, CAST(NULL AS STRING) AS midas_name, CAST(NULL AS STRING) AS midas_sitecode, CAST(NULL AS STRING) AS midas_sitename, CAST(NULL AS STRING) AS midas_spatialconformanceid, CAST(NULL AS DECIMAL(38,18)) AS midas_totalminedexpitmmintonnes, CAST(NULL AS TIMESTAMP) AS modifiedon, CAST(NULL AS INT) AS statecode WHERE 1=0
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ✓ Exported to sync_config_table_dataverse.csv

# %%
# ─── Clean Up ──────────────────────────────────────────────────────────────────
databricks_cursor.close()
databricks_conn.close()
synapse_conn.close()
print("Connections closed.")
